# %% [markdown]
# # Chemical and cancer phases analysis

# %% [markdown]
# ## libraries import

# %%
import os
import gc
import re
import requests
import time
import random

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from tqdm import tqdm
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

import seaborn as sns
import networkx as nx
import statsmodels.api as sm
import statsmodels.formula.api as smf

from statsmodels.stats import diagnostic
from scipy import stats

from src.drugbank_XML_drugparser import DrugParser
from src.drugbank_bindingdb_merger import DrugBank_BindingDB_Merger
from src.preprocessing import Preprocessing, ColumnClean

from matplotlib.patches import Circle
import matplotlib.patches as mpatches

from src.data_paths import *

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Dataframes imports

# %%
# loads bindingDB and Drugbank merged
merged_df = pd.read_pickle(MERGED)

# %%
merged_df.columns
# Out:
# Index(['ki', 'ph', 'temp', 'ic50', 'ec50', 'kd', 'kon', 'koff', 'doi',
#        'target_name', 'ligand_name', 'pubchem_cid', 'chebi_id', 'chembl_id',
#        'drugbank_id', 'kegg_id', 'zinc_id', 'smiles', 'inchi_key',
#        'bindingdb_id', 'swissprot_target_chain_name',
#        'swissprot_target_chain_entry_name', 'swissprot_protein_id',
#        'Unique_ID', 'drugbank_drug_name', 'drugbank_drug_unii',
#        'drugbank_drug_toxicity', 'drugbank_drug_class_kingdom',
#        'drugbank_drug_class_superclass', 'drugbank_drug_synonyms',
#        'drugbank_drug_categories', 'drugbank_drug_patent_approved',
#        'drugbank_drug_interaction', 'Matched_On', 'drugbank_protein_name',
#        'drugbank_protein_general_function',
#        'drugbank_protein_specific_function', 'drugbank_protein_organism'],
#       dtype='object')

# %%
# loads cancerous protein dataframe
protein_classes = pd.read_csv("data/clean/protein_class_COSMIC.tsv", sep='\t')

for col in protein_classes.columns:
    print(col)
protein_classes
# Out:
# Gene
# Gene synonym
# Ensembl
# Gene description
# Uniprot
# Chromosome
# Position
# Protein class
# Biological process
# Molecular function
# Disease involvement
# Evidence
# HPA evidence
# UniProt evidence
# NeXtProt evidence
# RNA tissue specificity
# RNA tissue distribution
# RNA tissue specificity score
# RNA tissue specific nTPM
# RNA single cell type specificity
# RNA single cell type distribution
# RNA single cell type specificity score
# RNA single cell type specific nTPM
# RNA single nuclei brain specificity
# RNA single nuclei brain distribution
# RNA single nuclei brain specificity score
# RNA single nuclei brain specific nTPM
# RNA cancer specificity
# RNA cancer distribution
# RNA cancer specificity score
# RNA cancer specific FPKM
# RNA brain regional specificity
# RNA brain regional distribution
# RNA brain regional specificity score
# RNA brain regional specific nTPM
# RNA blood cell specificity
# RNA blood cell distribution
# RNA blood cell specificity score
# RNA blood cell specific nTPM
# RNA blood lineage specificity
# RNA blood lineage distribution
# RNA blood lineage specificity score
# RNA blood lineage specific nTPM
# RNA cell line specificity
# RNA cell line distribution
# RNA cell line specificity score
# RNA cell line specific nTPM
# RNA tissue cell type enrichment
# RNA mouse brain regional specificity
# RNA mouse brain regional distribution
# RNA mouse brain regional specificity score
# RNA mouse brain regional specific nTPM
# RNA pig brain regional specificity
# RNA pig brain regional distribution
# RNA pig brain regional specificity score
# RNA pig brain regional specific nTPM
# Antibody
# Reliability (IH)
# Reliability (Mouse Brain)
# Reliability (IF)
# Subcellular location
# Secretome location
# Secretome function
# CCD Protein
# CCD Transcript
# Blood concentration - Conc. blood IM [pg/L]
# Blood concentration - Conc. blood MS [pg/L]
# Blood expression cluster
# Tissue expression cluster
# Brain expression cluster
# Cell line expression cluster
# Single cell expression cluster
# Interactions
# Subcellular main location
# Subcellular additional location
# Antibody RRID
# Cancer prognostics - Bladder Urothelial Carcinoma (TCGA)
# Cancer prognostics - Breast Invasive Carcinoma (TCGA)
# Cancer prognostics - Breast Invasive Carcinoma (validation)
# Cancer prognostics - Cervical Squamous Cell Carcinoma and Endocervical Adenocarcinoma (TCGA)
# Cancer prognostics - Colon Adenocarcinoma (TCGA)
# Cancer prognostics - Colon Adenocarcinoma (validation)
# Cancer prognostics - Glioblastoma Multiforme (TCGA)
# Cancer prognostics - Glioblastoma Multiforme (validation)
# Cancer prognostics - Head and Neck Squamous Cell Carcinoma (TCGA)
# Cancer prognostics - Kidney Chromophobe (TCGA)
# Cancer prognostics - Kidney Renal Clear Cell Carcinoma (TCGA)
# Cancer prognostics - Kidney Renal Clear Cell Carcinoma (validation)
# Cancer prognostics - Kidney Renal Papillary Cell Carcinoma (TCGA)
# Cancer prognostics - Liver Hepatocellular Carcinoma (TCGA)
# Cancer prognostics - Liver Hepatocellular Carcinoma (validation)
# Cancer prognostics - Lung Adenocarcinoma (TCGA)
# Cancer prognostics - Lung Adenocarcinoma (validation)
# Cancer prognostics - Lung Squamous Cell Carcinoma (TCGA)
# Cancer prognostics - Lung Squamous Cell Carcinoma (validation)
# Cancer prognostics - Ovary Serous Cystadenocarcinoma (TCGA)
# Cancer prognostics - Ovary Serous Cystadenocarcinoma (validation)
# Cancer prognostics - Pancreatic Adenocarcinoma (TCGA)
# Cancer prognostics - Pancreatic Adenocarcinoma (validation)
# Cancer prognostics - Prostate Adenocarcinoma (TCGA)
# Cancer prognostics - Rectum Adenocarcinoma (TCGA)
# Cancer prognostics - Rectum Adenocarcinoma (validation)
# Cancer prognostics - Skin Cuteneous Melanoma (TCGA)
# Cancer prognostics - Stomach Adenocarcinoma (TCGA)
# Cancer prognostics - Testicular Germ Cell Tumor (TCGA)
# Cancer prognostics - Thyroid Carcinoma (TCGA)
# Cancer prognostics - Uterine Corpus Endometrial Carcinoma (TCGA)
#        Gene                     Gene synonym          Ensembl  \
# 0      ABI1             ABI-1, E3B1, SSH3BP1  ENSG00000136754
# 1      ABL1           ABL, c-ABL, JTK7, p150  ENSG00000097007
# 2      ABL2                        ABLL, ARG  ENSG00000143322
# 3     ACKR3      CMKOR1, CXCR7, GPR159, RDC1  ENSG00000144476
# 4     ACSL3             ACS3, FACL3, PRO2194  ENSG00000123983
# ..      ...                              ...              ...
# 567   ZMYM2           FIM, MYM, RAMP, ZNF198  ENSG00000121741
# 568  ZNF331             RITA, ZNF361, ZNF463  ENSG00000130844
# 569  ZNF384     CAGH1A, CIZ, NMP4, NP, TNRC1  ENSG00000126746
# 570  ZNF521                       EHZF, Evi3  ENSG00000198795
# 571   ZRSR2  U2AF1-RS2, U2AF1L2, URP, ZC3H22  ENSG00000169249
#
#                                       Gene description Uniprot Chromosome  \
# 0                                     Abl interactor 1  Q8IZP0         10
# 1    ABL proto-oncogene 1, non-receptor tyrosine ki...  P00519          9
# 2    ABL proto-oncogene 2, non-receptor tyrosine ki...  P42684          1
# 3                        Atypical chemokine receptor 3  P25106          2
# 4       Acyl-CoA synthetase long chain family member 3  O95573          2
# ..                                                 ...     ...        ...
# 567                  Zinc finger MYM-type containing 2  Q9UBW7         13
# 568                            Zinc finger protein 331  Q9NQX6         19
# 569                            Zinc finger protein 384  Q8TF68         12
# 570                            Zinc finger protein 521  Q96K83         18
# 571  Zinc finger CCCH-type, RNA binding motif and s...  Q15696          X
#
#                 Position                                      Protein class  \
# 0      26746593-26861087  Cancer-related genes, Disease related genes, P...
# 1    130713043-130887675  Cancer-related genes, Disease related genes, E...
# 2    179099330-179229684  Cancer-related genes, Enzymes, Predicted intra...
# 3    236567787-236582354  Cancer-related genes, Disease related genes, G...
# 4    222860942-222944639  Cancer-related genes, Enzymes, Metabolic prote...
# ..                   ...                                                ...
# 567    19958677-20091829  Cancer-related genes, Disease related genes, H...
# 568    53519527-53580269  Cancer-related genes, Predicted intracellular ...
# 569      6666477-6689572  Cancer-related genes, Predicted intracellular ...
# 570    25061924-25352190  Cancer-related genes, Disease related genes, P...
# 571    15790156-15830694  Cancer-related genes, Human disease related ge...
#
#                                     Biological process  \
# 0                               Host-virus interaction
# 1    Apoptosis, Autophagy, Cell adhesion, DNA damag...
# 2                                        Cell adhesion
# 3                Cell adhesion, Host-virus interaction
# 4              Fatty acid metabolism, Lipid metabolism
# ..                                                 ...
# 567            Transcription, Transcription regulation
# 568            Transcription, Transcription regulation
# 569            Transcription, Transcription regulation
# 570  Differentiation, Transcription, Transcription ...
# 571                     mRNA processing, mRNA splicing
#
#                                     Molecular function  ...  \
# 0                                                  NaN  ...
# 1    DNA-binding, Kinase, Transferase, Tyrosine-pro...  ...
# 2         Kinase, Transferase, Tyrosine-protein kinase  ...
# 3    Developmental protein, G-protein coupled recep...  ...
# 4                                               Ligase  ...
# ..                                                 ...  ...
# 567                                                NaN  ...
# 568                                        DNA-binding  ...
# 569                                        DNA-binding  ...
# 570  Activator, Developmental protein, DNA-binding,...  ...
# 571                     Ribonucleoprotein, RNA-binding  ...
#
#     Cancer prognostics - Pancreatic Adenocarcinoma (TCGA)  \
# 0                               unprognostic (6.17e-3)
# 1                               unprognostic (6.12e-2)
# 2                               unprognostic (2.27e-2)
# 3                               unprognostic (1.48e-3)
# 4                               unprognostic (7.65e-2)
# ..                                                 ...
# 567                             unprognostic (3.57e-2)
# 568                             unprognostic (1.35e-2)
# 569                             unprognostic (4.00e-2)
# 570                             unprognostic (1.42e-1)
# 571                             unprognostic (6.11e-2)
#
#     Cancer prognostics - Pancreatic Adenocarcinoma (validation)  \
# 0                               unprognostic (9.66e-2)
# 1                               unprognostic (3.31e-2)
# 2                               unprognostic (1.90e-3)
# 3                               unprognostic (8.51e-2)
# 4                               unprognostic (1.24e-1)
# ..                                                 ...
# 567                             unprognostic (4.85e-1)
# 568                             unprognostic (4.71e-2)
# 569                             unprognostic (2.98e-2)
# 570                             unprognostic (1.84e-1)
# 571                             unprognostic (1.82e-2)
#
#     Cancer prognostics - Prostate Adenocarcinoma (TCGA)  \
# 0                               unprognostic (8.60e-2)
# 1                               unprognostic (1.27e-1)
# 2                               unprognostic (1.86e-1)
# 3                               unprognostic (3.54e-2)
# 4                               unprognostic (2.88e-2)
# ..                                                 ...
# 567                             unprognostic (1.21e-1)
# 568                             unprognostic (4.12e-1)
# 569                             unprognostic (4.39e-1)
# 570                             unprognostic (1.20e-1)
# 571                             unprognostic (9.56e-2)
#
#     Cancer prognostics - Rectum Adenocarcinoma (TCGA)  \
# 0                              unprognostic (1.16e-1)
# 1                              unprognostic (2.01e-2)
# 2                              unprognostic (1.08e-1)
# 3                              unprognostic (1.21e-1)
# 4                              unprognostic (3.03e-1)
# ..                                                ...
# 567                            unprognostic (4.77e-2)
# 568                            unprognostic (2.69e-1)
# 569                            unprognostic (5.84e-3)
# 570                            unprognostic (1.82e-1)
# 571                            unprognostic (3.04e-1)
#
#     Cancer prognostics - Rectum Adenocarcinoma (validation)  \
# 0                               unprognostic (3.28e-2)
# 1                               unprognostic (2.18e-1)
# 2                               unprognostic (7.21e-2)
# 3                               unprognostic (4.76e-3)
# 4                               unprognostic (2.64e-2)
# ..                                                 ...
# 567                             unprognostic (1.74e-1)
# 568                             unprognostic (5.47e-3)
# 569                             unprognostic (3.16e-2)
# 570                             unprognostic (3.00e-3)
# 571                             unprognostic (2.59e-1)
#
#     Cancer prognostics - Skin Cuteneous Melanoma (TCGA)  \
# 0                               unprognostic (1.01e-1)
# 1                               unprognostic (2.61e-1)
# 2                               unprognostic (2.24e-1)
# 3                               unprognostic (1.29e-2)
# 4                               unprognostic (8.26e-2)
# ..                                                 ...
# 567                             unprognostic (7.15e-2)
# 568                             unprognostic (1.28e-2)
# 569                             unprognostic (8.91e-2)
# 570                             unprognostic (8.14e-2)
# 571                             unprognostic (1.31e-1)
#
#     Cancer prognostics - Stomach Adenocarcinoma (TCGA)  \
# 0                               unprognostic (3.66e-1)
# 1                               unprognostic (8.92e-2)
# 2                               unprognostic (9.34e-2)
# 3                               unprognostic (1.95e-4)
# 4                               unprognostic (9.29e-2)
# ..                                                 ...
# 567                             unprognostic (2.15e-1)
# 568                             unprognostic (1.03e-3)
# 569                             unprognostic (6.88e-2)
# 570                             unprognostic (7.27e-4)
# 571                             unprognostic (4.48e-2)
#
#      Cancer prognostics - Testicular Germ Cell Tumor (TCGA)  \
# 0                               unprognostic (1.72e-1)
# 1                               unprognostic (3.15e-1)
# 2                               unprognostic (1.59e-1)
# 3                               unprognostic (1.41e-1)
# 4                               unprognostic (1.77e-1)
# ..                                                 ...
# 567                             unprognostic (1.08e-1)
# 568                             unprognostic (1.42e-1)
# 569                             unprognostic (2.63e-1)
# 570                             unprognostic (1.95e-1)
# 571                             unprognostic (1.40e-1)
#
#     Cancer prognostics - Thyroid Carcinoma (TCGA)  \
# 0                          unprognostic (1.03e-1)
# 1                          unprognostic (1.29e-1)
# 2                          unprognostic (2.71e-2)
# 3                          unprognostic (1.15e-3)
# 4                          unprognostic (1.08e-1)
# ..                                            ...
# 567                        unprognostic (3.70e-3)
# 568                        unprognostic (2.32e-4)
# 569                        unprognostic (9.21e-2)
# 570                        unprognostic (2.37e-3)
# 571                        unprognostic (2.32e-1)
#
#     Cancer prognostics - Uterine Corpus Endometrial Carcinoma (TCGA)
# 0                               unprognostic (1.72e-1)
# 1                               unprognostic (1.96e-2)
# 2                               unprognostic (5.39e-2)
# 3                               unprognostic (4.99e-2)
# 4                               unprognostic (2.19e-1)
# ..                                                 ...
# 567                             unprognostic (1.30e-1)
# 568                             unprognostic (3.34e-2)
# 569                             unprognostic (4.33e-1)
# 570                             unprognostic (3.29e-2)
# 571                             unprognostic (1.15e-1)
#
# [572 rows x 107 columns]

# %%
# Additional proteins 
highly_studied_proteins = [
    'Cytochrome P450 3A4', 
    'Epidermal growth factor receptor', 
    'Proto-oncogene tyrosine-protein kinase Src', 
    'Vascular endothelial growth factor receptor 2', 
    'Adenosine receptor A2a', 'Cytochrome P450 2C9', 
    'Cytochrome P450 1A2', 'Cytochrome P450 2C19', 
    'Cytochrome P450 2D6', 
    'Prostaglandin G/H synthase 1', 
    'Prostaglandin G/H synthase 2'
    ]

# %%
# create lists of the relevant columns to identify cancerous proteins
cancer_proteins = list(protein_classes["Gene"].dropna().values)
genes_uniprot = list(protein_classes["Uniprot"].astype(str).dropna().values)

# %%
# joins all targeted proteins 
pattern_protein_names = '|'.join(rf"\b{re.escape(term)}\b" for term in cancer_proteins)
pattern_gene_names =  '|'.join(rf"\b{re.escape(term)}\b" for term in genes_uniprot)
pattern_highly_studied =  '|'.join(rf"\b{re.escape(term)}\b" for term in highly_studied_proteins)

#test
#pattern_protein_names

# extract rows based on the columns that contain cancer_keywords 
filtered_df = merged_df[
    #merged_df['drugbank_drug_unii'].str.contains(pattern_protein_names, case=False, na=False) |
    #merged_df['swissprot_target_chain_name'].str.contains(pattern_protein_names, case=False, na=False) |
    #merged_df['swissprot_protein_id'].str.contains(pattern_gene_names, case=False, na=False) |
    #merged_df['drugbank_protein_name'].str.contains(pattern_protein_names, case=False, na=False)|
    #merged_df['target_name'].str.contains(pattern_highly_studied, case=False, na=False)
    merged_df['target_name'].isin(highly_studied_proteins)
]
filtered_df.reset_index(inplace=True)


print(filtered_df.shape)
filtered_df.head()
# Out:
# (103259, 39)
#    index    ki    ph  temp     ic50  ec50    kd   kon  koff  \
# 0    142  <NA>  <NA>  <NA>  50000.0  <NA>  <NA>  <NA>  <NA>
# 1   3775  <NA>   7.5  20.0    800.0  <NA>  <NA>  <NA>  <NA>
# 2   3776  <NA>   7.5  20.0    220.0  <NA>  <NA>  <NA>  <NA>
# 3   3777  <NA>   7.5  20.0    160.0  <NA>  <NA>  <NA>  <NA>
# 4   3778  <NA>   7.5  20.0     58.0  <NA>  <NA>  <NA>  <NA>
#
#                  doi  ... drugbank_drug_class_superclass  \
# 0               <NA>  ...                            NaN
# 1  10.1021/jm970124v  ...                            NaN
# 2  10.1021/jm970124v  ...                            NaN
# 3  10.1021/jm970124v  ...                            NaN
# 4  10.1021/jm970124v  ...                            NaN
#
#   drugbank_drug_synonyms  drugbank_drug_categories  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
#    drugbank_drug_patent_approved drugbank_drug_interaction Matched_On  \
# 0                            NaN                       NaN        NaN
# 1                            NaN                       NaN        NaN
# 2                            NaN                       NaN        NaN
# 3                            NaN                       NaN        NaN
# 4                            NaN                       NaN        NaN
#
#   drugbank_protein_name drugbank_protein_general_function  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   drugbank_protein_specific_function drugbank_protein_organism
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
#
# [5 rows x 39 columns]

# %%
# Create a new column to distinguish rows with and without `drugbank_drug_name`
filtered_df['drugbank_drug_name_present'] = filtered_df['drugbank_drug_name'].notna().map({True: 'With DrugBank Drug', False: 'Without DrugBank Drug'})
# Out:
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_12604\4122900635.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['drugbank_drug_name_present'] = filtered_df['drugbank_drug_name'].notna().map({True: 'With DrugBank Drug', False: 'Without DrugBank Drug'})

# %% [markdown]
# # Chemical metrics of affinity

# %% [markdown]
# ## First look

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.boxplot(data=filtered_df[filtered_df.kd.notna()], x="target_name", y="kd")
plt.yscale("log")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### ki

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=filtered_df[filtered_df['ki'].notna()],  # Exclude rows with NaN `ki`
    x="target_name",
    y="ki",
    hue="drugbank_drug_name_present"  # Use the new column to separate groups
)
plt.yscale("log")  # Set y-axis to log scale
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("KI values by Protein and DrugBank Drug Presence", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("KI (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ### IC50

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=filtered_df[filtered_df['ic50'].notna()],  # Exclude rows with NaN `ki`
    x="target_name",
    y="ic50",
    hue="drugbank_drug_name_present"  # Use the new column to separate groups
)
plt.yscale("log")  # Set y-axis to log scale
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("IC50 values by Protein and DrugBank Drug Presence", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("IC50 (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
#plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ### EC50

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=filtered_df[filtered_df['ec50'].notna()].drop_duplicates(),  # Exclude rows with NaN `ki`
    x="target_name",
    y="ec50",
    hue="drugbank_drug_name_present",  # Use the new column to separate groups
)
plt.yscale("log")  # Set y-axis to log scale
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("EC50 values by Protein and DrugBank Drug Presence", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("EC50 (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
#plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# #### Naive plotting

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=filtered_df[filtered_df['ec50'].notna()],  # Exclude rows with NaN `ki`
    x="target_name",
    y="ec50",
    hue="drugbank_drug_name_present"  # Use the new column to separate groups
)
plt.yscale("log")  # Set y-axis to log scale
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("EC50 values by Protein and DrugBank Drug Presence", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("EC50 (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
plt.tight_layout()
plt.grid("y")
plt.show()

# %% [markdown]
# #### Selecting n largest elements of each group

# %%
# Step 3: Group by `target_name` and select the top N largest values per group
balanced_data = pd.DataFrame()  # To store the balanced dataset
for target in filtered_df['target_name'].unique():
    # Get subsets for each hue
    group_with = filtered_df[
        (filtered_df['target_name'] == target) & 
        (filtered_df['drugbank_drug_name_present'] == 'With DrugBank Drug')
    ].nlargest(n=len(filtered_df), columns='ec50')  # Sort by `ec50`
    
    group_without = filtered_df[
        (filtered_df['target_name'] == target) & 
        (filtered_df['drugbank_drug_name_present'] == 'Without DrugBank Drug')
    ].nlargest(n=len(filtered_df), columns='ec50')
    
    # Find the smaller group size
    min_size = min(len(group_with), len(group_without))
    
    # Select the top N largest `ec50` values for both groups
    balanced_data = pd.concat([
        balanced_data,
        group_without.nlargest(n=min_size, columns='ec50'),
        group_with.nlargest(n=min_size, columns='ec50')
    ])

print(balanced_data[["target_name", "drugbank_drug_name_present", "ec50"]])

# Step 4: Plot the boxplot
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=balanced_data, 
    x="target_name",
    y="ec50",
    hue="drugbank_drug_name_present"
)

# Customize the plot
plt.yscale("log")
plt.xticks(rotation=90)
plt.title("EC50 values by Protein and DrugBank Drug Presence (Balanced Data)", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("EC50 (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
plt.tight_layout()
plt.grid("y")
plt.show()
# Out:
#                          target_name drugbank_drug_name_present      ec50
# 62057            Cytochrome P450 3A4      Without DrugBank Drug  100000.0
# 96486            Cytochrome P450 3A4      Without DrugBank Drug  100000.0
# 89588            Cytochrome P450 3A4      Without DrugBank Drug   89000.0
# 62059            Cytochrome P450 3A4      Without DrugBank Drug   60000.0
# 62058            Cytochrome P450 3A4      Without DrugBank Drug   60000.0
# ...                              ...                        ...       ...
# 102975  Prostaglandin G/H synthase 2         With DrugBank Drug      <NA>
# 103005  Prostaglandin G/H synthase 2         With DrugBank Drug      <NA>
# 103030  Prostaglandin G/H synthase 2         With DrugBank Drug      <NA>
# 103031  Prostaglandin G/H synthase 2         With DrugBank Drug      <NA>
# 103239  Prostaglandin G/H synthase 2         With DrugBank Drug      <NA>
#
# [16604 rows x 3 columns]

# %% [markdown]
# ##### visualizing the number of drugs per protein

# %%
filtered_df.groupby(['target_name', 'drugbank_drug_name_present']).count()
# Out:
#                                                                           index  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            468
#                                               Without DrugBank Drug       13519
# Cytochrome P450 1A2                           With DrugBank Drug            315
#                                               Without DrugBank Drug        3885
# Cytochrome P450 2C19                          With DrugBank Drug            264
#                                               Without DrugBank Drug        3210
# Cytochrome P450 2C9                           With DrugBank Drug            397
#                                               Without DrugBank Drug        5324
# Cytochrome P450 2D6                           With DrugBank Drug            424
#                                               Without DrugBank Drug        6211
# Cytochrome P450 3A4                           With DrugBank Drug            769
#                                               Without DrugBank Drug        9492
# Epidermal growth factor receptor              With DrugBank Drug           2474
#                                               Without DrugBank Drug       18565
# Prostaglandin G/H synthase 1                  With DrugBank Drug            960
#                                               Without DrugBank Drug        6480
# Prostaglandin G/H synthase 2                  With DrugBank Drug           1068
#                                               Without DrugBank Drug        8771
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            363
#                                               Without DrugBank Drug        6189
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            800
#                                               Without DrugBank Drug       13311
#
#                                                                              ki  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            413
#                                               Without DrugBank Drug       10201
# Cytochrome P450 1A2                           With DrugBank Drug             15
#                                               Without DrugBank Drug          44
# Cytochrome P450 2C19                          With DrugBank Drug              9
#                                               Without DrugBank Drug          50
# Cytochrome P450 2C9                           With DrugBank Drug             32
#                                               Without DrugBank Drug          98
# Cytochrome P450 2D6                           With DrugBank Drug             37
#                                               Without DrugBank Drug         113
# Cytochrome P450 3A4                           With DrugBank Drug             65
#                                               Without DrugBank Drug         146
# Epidermal growth factor receptor              With DrugBank Drug             33
#                                               Without DrugBank Drug         437
# Prostaglandin G/H synthase 1                  With DrugBank Drug             87
#                                               Without DrugBank Drug          28
# Prostaglandin G/H synthase 2                  With DrugBank Drug            110
#                                               Without DrugBank Drug          64
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug              8
#                                               Without DrugBank Drug         476
# Vascular endothelial growth factor receptor 2 With DrugBank Drug             24
#                                               Without DrugBank Drug         569
#
#                                                                             ph  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug             3
#                                               Without DrugBank Drug        236
# Cytochrome P450 1A2                           With DrugBank Drug             0
#                                               Without DrugBank Drug          7
# Cytochrome P450 2C19                          With DrugBank Drug             0
#                                               Without DrugBank Drug         25
# Cytochrome P450 2C9                           With DrugBank Drug             1
#                                               Without DrugBank Drug         24
# Cytochrome P450 2D6                           With DrugBank Drug             3
#                                               Without DrugBank Drug         27
# Cytochrome P450 3A4                           With DrugBank Drug            18
#                                               Without DrugBank Drug        454
# Epidermal growth factor receptor              With DrugBank Drug            26
#                                               Without DrugBank Drug       1041
# Prostaglandin G/H synthase 1                  With DrugBank Drug            17
#                                               Without DrugBank Drug        146
# Prostaglandin G/H synthase 2                  With DrugBank Drug            16
#                                               Without DrugBank Drug         97
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            17
#                                               Without DrugBank Drug        322
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            34
#                                               Without DrugBank Drug       2011
#
#                                                                           temp  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug             3
#                                               Without DrugBank Drug        224
# Cytochrome P450 1A2                           With DrugBank Drug             0
#                                               Without DrugBank Drug         39
# Cytochrome P450 2C19                          With DrugBank Drug             1
#                                               Without DrugBank Drug        103
# Cytochrome P450 2C9                           With DrugBank Drug             3
#                                               Without DrugBank Drug        128
# Cytochrome P450 2D6                           With DrugBank Drug             2
#                                               Without DrugBank Drug         77
# Cytochrome P450 3A4                           With DrugBank Drug            16
#                                               Without DrugBank Drug        409
# Epidermal growth factor receptor              With DrugBank Drug            25
#                                               Without DrugBank Drug       1007
# Prostaglandin G/H synthase 1                  With DrugBank Drug            16
#                                               Without DrugBank Drug        147
# Prostaglandin G/H synthase 2                  With DrugBank Drug            20
#                                               Without DrugBank Drug        179
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            19
#                                               Without DrugBank Drug        621
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            35
#                                               Without DrugBank Drug       1819
#
#                                                                            ic50  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug             32
#                                               Without DrugBank Drug        2835
# Cytochrome P450 1A2                           With DrugBank Drug            299
#                                               Without DrugBank Drug        3817
# Cytochrome P450 2C19                          With DrugBank Drug            254
#                                               Without DrugBank Drug        3141
# Cytochrome P450 2C9                           With DrugBank Drug            364
#                                               Without DrugBank Drug        5195
# Cytochrome P450 2D6                           With DrugBank Drug            386
#                                               Without DrugBank Drug        6079
# Cytochrome P450 3A4                           With DrugBank Drug            699
#                                               Without DrugBank Drug        9302
# Epidermal growth factor receptor              With DrugBank Drug           1338
#                                               Without DrugBank Drug       17390
# Prostaglandin G/H synthase 1                  With DrugBank Drug            868
#                                               Without DrugBank Drug        6444
# Prostaglandin G/H synthase 2                  With DrugBank Drug            954
#                                               Without DrugBank Drug        8688
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            239
#                                               Without DrugBank Drug        5252
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            655
#                                               Without DrugBank Drug       12457
#
#                                                                           ec50  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            13
#                                               Without DrugBank Drug        401
# Cytochrome P450 1A2                           With DrugBank Drug             1
#                                               Without DrugBank Drug         24
# Cytochrome P450 2C19                          With DrugBank Drug             1
#                                               Without DrugBank Drug         19
# Cytochrome P450 2C9                           With DrugBank Drug             1
#                                               Without DrugBank Drug         29
# Cytochrome P450 2D6                           With DrugBank Drug             1
#                                               Without DrugBank Drug         19
# Cytochrome P450 3A4                           With DrugBank Drug             4
#                                               Without DrugBank Drug         25
# Epidermal growth factor receptor              With DrugBank Drug            39
#                                               Without DrugBank Drug        284
# Prostaglandin G/H synthase 1                  With DrugBank Drug             0
#                                               Without DrugBank Drug          1
# Prostaglandin G/H synthase 2                  With DrugBank Drug             0
#                                               Without DrugBank Drug          2
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug             3
#                                               Without DrugBank Drug        398
# Vascular endothelial growth factor receptor 2 With DrugBank Drug             4
#                                               Without DrugBank Drug         48
#
#                                                                             kd  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            10
#                                               Without DrugBank Drug         67
# Cytochrome P450 1A2                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2C19                          With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2C9                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2D6                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 3A4                           With DrugBank Drug             1
#                                               Without DrugBank Drug         19
# Epidermal growth factor receptor              With DrugBank Drug          1066
#                                               Without DrugBank Drug        489
# Prostaglandin G/H synthase 1                  With DrugBank Drug             5
#                                               Without DrugBank Drug          7
# Prostaglandin G/H synthase 2                  With DrugBank Drug             4
#                                               Without DrugBank Drug         17
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug           115
#                                               Without DrugBank Drug         56
# Vascular endothelial growth factor receptor 2 With DrugBank Drug           117
#                                               Without DrugBank Drug        266
#
#                                                                           kon  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Cytochrome P450 1A2                           With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Cytochrome P450 2C19                          With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Cytochrome P450 2C9                           With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Cytochrome P450 2D6                           With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Cytochrome P450 3A4                           With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Epidermal growth factor receptor              With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Prostaglandin G/H synthase 1                  With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Prostaglandin G/H synthase 2                  With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            0
#                                               Without DrugBank Drug         0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            0
#                                               Without DrugBank Drug         0
#
#                                                                           koff  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 1A2                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2C19                          With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2C9                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 2D6                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Cytochrome P450 3A4                           With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Epidermal growth factor receptor              With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Prostaglandin G/H synthase 1                  With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Prostaglandin G/H synthase 2                  With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug             0
#                                               Without DrugBank Drug          0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug             0
#                                               Without DrugBank Drug          0
#
#                                                                             doi  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug            412
#                                               Without DrugBank Drug        9518
# Cytochrome P450 1A2                           With DrugBank Drug            281
#                                               Without DrugBank Drug        3182
# Cytochrome P450 2C19                          With DrugBank Drug            230
#                                               Without DrugBank Drug        2565
# Cytochrome P450 2C9                           With DrugBank Drug            346
#                                               Without DrugBank Drug        4417
# Cytochrome P450 2D6                           With DrugBank Drug            383
#                                               Without DrugBank Drug        5268
# Cytochrome P450 3A4                           With DrugBank Drug            614
#                                               Without DrugBank Drug        7595
# Epidermal growth factor receptor              With DrugBank Drug           2060
#                                               Without DrugBank Drug       11369
# Prostaglandin G/H synthase 1                  With DrugBank Drug            900
#                                               Without DrugBank Drug        6287
# Prostaglandin G/H synthase 2                  With DrugBank Drug            978
#                                               Without DrugBank Drug        7984
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug            319
#                                               Without DrugBank Drug        4303
# Vascular endothelial growth factor receptor 2 With DrugBank Drug            696
#                                               Without DrugBank Drug        8464
#
#                                                                           ...  \
# target_name                                   drugbank_drug_name_present  ...
# Adenosine receptor A2a                        With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Cytochrome P450 1A2                           With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Cytochrome P450 2C19                          With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Cytochrome P450 2C9                           With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Cytochrome P450 2D6                           With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Cytochrome P450 3A4                           With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Epidermal growth factor receptor              With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Prostaglandin G/H synthase 1                  With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Prostaglandin G/H synthase 2                  With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
# Vascular endothelial growth factor receptor 2 With DrugBank Drug          ...
#                                               Without DrugBank Drug       ...
#
#                                                                           drugbank_drug_class_superclass  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                     451
#                                               Without DrugBank Drug                                    0
# Cytochrome P450 1A2                           With DrugBank Drug                                     233
#                                               Without DrugBank Drug                                    0
# Cytochrome P450 2C19                          With DrugBank Drug                                     188
#                                               Without DrugBank Drug                                    0
# Cytochrome P450 2C9                           With DrugBank Drug                                     305
#                                               Without DrugBank Drug                                    0
# Cytochrome P450 2D6                           With DrugBank Drug                                     328
#                                               Without DrugBank Drug                                    0
# Cytochrome P450 3A4                           With DrugBank Drug                                     635
#                                               Without DrugBank Drug                                    0
# Epidermal growth factor receptor              With DrugBank Drug                                    2237
#                                               Without DrugBank Drug                                    0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                     908
#                                               Without DrugBank Drug                                    0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                                    1009
#                                               Without DrugBank Drug                                    0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                     324
#                                               Without DrugBank Drug                                    0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                     729
#                                               Without DrugBank Drug                                    0
#
#                                                                           drugbank_drug_synonyms  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                             387
#                                               Without DrugBank Drug                            0
# Cytochrome P450 1A2                           With DrugBank Drug                             258
#                                               Without DrugBank Drug                            0
# Cytochrome P450 2C19                          With DrugBank Drug                             209
#                                               Without DrugBank Drug                            0
# Cytochrome P450 2C9                           With DrugBank Drug                             316
#                                               Without DrugBank Drug                            0
# Cytochrome P450 2D6                           With DrugBank Drug                             346
#                                               Without DrugBank Drug                            0
# Cytochrome P450 3A4                           With DrugBank Drug                             639
#                                               Without DrugBank Drug                            0
# Epidermal growth factor receptor              With DrugBank Drug                            2204
#                                               Without DrugBank Drug                            0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                             932
#                                               Without DrugBank Drug                            0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                            1040
#                                               Without DrugBank Drug                            0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                             258
#                                               Without DrugBank Drug                            0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                             646
#                                               Without DrugBank Drug                            0
#
#                                                                           drugbank_drug_categories  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                               366
#                                               Without DrugBank Drug                              0
# Cytochrome P450 1A2                           With DrugBank Drug                               271
#                                               Without DrugBank Drug                              0
# Cytochrome P450 2C19                          With DrugBank Drug                               221
#                                               Without DrugBank Drug                              0
# Cytochrome P450 2C9                           With DrugBank Drug                               336
#                                               Without DrugBank Drug                              0
# Cytochrome P450 2D6                           With DrugBank Drug                               372
#                                               Without DrugBank Drug                              0
# Cytochrome P450 3A4                           With DrugBank Drug                               681
#                                               Without DrugBank Drug                              0
# Epidermal growth factor receptor              With DrugBank Drug                              2303
#                                               Without DrugBank Drug                              0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                               947
#                                               Without DrugBank Drug                              0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                              1057
#                                               Without DrugBank Drug                              0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                               283
#                                               Without DrugBank Drug                              0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                               700
#                                               Without DrugBank Drug                              0
#
#                                                                           drugbank_drug_patent_approved  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                    115
#                                               Without DrugBank Drug                                   0
# Cytochrome P450 1A2                           With DrugBank Drug                                     82
#                                               Without DrugBank Drug                                   0
# Cytochrome P450 2C19                          With DrugBank Drug                                     85
#                                               Without DrugBank Drug                                   0
# Cytochrome P450 2C9                           With DrugBank Drug                                    100
#                                               Without DrugBank Drug                                   0
# Cytochrome P450 2D6                           With DrugBank Drug                                    168
#                                               Without DrugBank Drug                                   0
# Cytochrome P450 3A4                           With DrugBank Drug                                    353
#                                               Without DrugBank Drug                                   0
# Epidermal growth factor receptor              With DrugBank Drug                                   1457
#                                               Without DrugBank Drug                                   0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                    718
#                                               Without DrugBank Drug                                   0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                                    799
#                                               Without DrugBank Drug                                   0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                    151
#                                               Without DrugBank Drug                                   0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                    394
#                                               Without DrugBank Drug                                   0
#
#                                                                           drugbank_drug_interaction  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                192
#                                               Without DrugBank Drug                               0
# Cytochrome P450 1A2                           With DrugBank Drug                                143
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2C19                          With DrugBank Drug                                145
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2C9                           With DrugBank Drug                                237
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2D6                           With DrugBank Drug                                261
#                                               Without DrugBank Drug                               0
# Cytochrome P450 3A4                           With DrugBank Drug                                515
#                                               Without DrugBank Drug                               0
# Epidermal growth factor receptor              With DrugBank Drug                               1860
#                                               Without DrugBank Drug                               0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                904
#                                               Without DrugBank Drug                               0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                               1018
#                                               Without DrugBank Drug                               0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                206
#                                               Without DrugBank Drug                               0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                548
#                                               Without DrugBank Drug                               0
#
#                                                                           Matched_On  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                 468
#                                               Without DrugBank Drug                0
# Cytochrome P450 1A2                           With DrugBank Drug                 315
#                                               Without DrugBank Drug                0
# Cytochrome P450 2C19                          With DrugBank Drug                 264
#                                               Without DrugBank Drug                0
# Cytochrome P450 2C9                           With DrugBank Drug                 397
#                                               Without DrugBank Drug                0
# Cytochrome P450 2D6                           With DrugBank Drug                 424
#                                               Without DrugBank Drug                0
# Cytochrome P450 3A4                           With DrugBank Drug                 769
#                                               Without DrugBank Drug                0
# Epidermal growth factor receptor              With DrugBank Drug                2474
#                                               Without DrugBank Drug                0
# Prostaglandin G/H synthase 1                  With DrugBank Drug                 960
#                                               Without DrugBank Drug                0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                1068
#                                               Without DrugBank Drug                0
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                 363
#                                               Without DrugBank Drug                0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                 800
#                                               Without DrugBank Drug                0
#
#                                                                           drugbank_protein_name  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Cytochrome P450 1A2                           With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Cytochrome P450 2C19                          With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Cytochrome P450 2C9                           With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Cytochrome P450 2D6                           With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Cytochrome P450 3A4                           With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Epidermal growth factor receptor              With DrugBank Drug                             83
#                                               Without DrugBank Drug                         633
# Prostaglandin G/H synthase 1                  With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                              0
#                                               Without DrugBank Drug                           1
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                              0
#                                               Without DrugBank Drug                           0
#
#                                                                           drugbank_protein_general_function  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Cytochrome P450 1A2                           With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Cytochrome P450 2C19                          With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Cytochrome P450 2C9                           With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Cytochrome P450 2D6                           With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Cytochrome P450 3A4                           With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Epidermal growth factor receptor              With DrugBank Drug                                         83
#                                               Without DrugBank Drug                                     633
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       1
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                          0
#                                               Without DrugBank Drug                                       0
#
#                                                                           drugbank_protein_specific_function  \
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Cytochrome P450 1A2                           With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Cytochrome P450 2C19                          With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Cytochrome P450 2C9                           With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Cytochrome P450 2D6                           With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Cytochrome P450 3A4                           With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Epidermal growth factor receptor              With DrugBank Drug                                          83
#                                               Without DrugBank Drug                                      633
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        1
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                           0
#                                               Without DrugBank Drug                                        0
#
#                                                                           drugbank_protein_organism
# target_name                                   drugbank_drug_name_present
# Adenosine receptor A2a                        With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Cytochrome P450 1A2                           With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2C19                          With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2C9                           With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Cytochrome P450 2D6                           With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Cytochrome P450 3A4                           With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Epidermal growth factor receptor              With DrugBank Drug                                 83
#                                               Without DrugBank Drug                             633
# Prostaglandin G/H synthase 1                  With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Prostaglandin G/H synthase 2                  With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               1
# Proto-oncogene tyrosine-protein kinase Src    With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
# Vascular endothelial growth factor receptor 2 With DrugBank Drug                                  0
#                                               Without DrugBank Drug                               0
#
# [22 rows x 38 columns]

# %% [markdown]
# ### Kd

# %%
# Plot the data
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=filtered_df[filtered_df['kd'].notna()].drop_duplicates(),  # Exclude rows with NaN `ki`
    x="target_name",
    y="kd",
    hue="drugbank_drug_name_present",  # Use the new column to separate groups
)
plt.yscale("log")  # Set y-axis to log scale
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title("Kd values by Protein and DrugBank Drug Presence", fontsize=16)
plt.xlabel("DrugBank Protein Name", fontsize=14)
plt.ylabel("Kd (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
#plt.tight_layout()
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
chemical_param_list = ["ki", "kd", "ec50", "ic50"]

# Only cancer-related proteins
chemical_param_for_corr = filtered_df[chemical_param_list]
chemical_param_for_corr

# all proteins
merged_df_chemical_param = merged_df[chemical_param_list]

# %%
# Spearman's correlaiton coefficient 
correlation_matrix = merged_df_chemical_param.corr(method='pearson')

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(15, 15))  # Set the size of the plot
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f', cbar=True, square=True)
plt.title('Correlation Matrix Heatmap of affinity parameters', size=20)
plt.show()

# %%
custom_palette = {
    "Without DrugBank Drug": "royalblue",    # Assign "blue" to "Present"
    "With DrugBank Drug": "orange",   # Assign "orange" to "Absent"
}

BOXPLOT_MINIMUM_COUNT = 5

fig, axes = plt.subplots(2, 2, figsize=(20, 15))

axes = axes.flatten()

for i, col in enumerate(chemical_param_list):
    data = filtered_df[(filtered_df[col].notna())].drop_duplicates()

    counts = data.groupby(["target_name", "drugbank_drug_name_present"]).size().unstack(fill_value=0)
    valid_targets = counts[
        (counts["Without DrugBank Drug"] >= BOXPLOT_MINIMUM_COUNT) & (counts["With DrugBank Drug"] >= BOXPLOT_MINIMUM_COUNT)
    ].index
    filtered_data = data[data["target_name"].isin(valid_targets)]


    if not filtered_data.empty:

        sns.boxplot(
            data=filtered_data,
            x="target_name",
            y=col,
            hue="drugbank_drug_name_present",  # Group by DrugBank drug presence
            ax=axes[i], 
            palette=custom_palette,
            # width=0.2,
            # dodge=True
        )
        
        axes[i].set_yscale("log")
        axes[i].tick_params(axis='x', rotation=30)
        for tick in axes[i].get_xticklabels():
            tick.set_ha('right')

        axes[i].set_title(f"{col} by Protein and DrugBank Drug Presence", fontsize=16)
        axes[i].set_ylabel(f"{col} (log scale)", fontsize=10)
        axes[i].set_xlabel("")
        
        axes[i].legend(title="", fontsize=10, loc='upper right')
        axes[i].grid(axis="y")

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
print("pH:", filtered_df["ph"].unique())
print("Temperatures:", filtered_df["temp"].unique())
sns.histplot(x="ph", y="temp", data=filtered_df, cbar=True)
plt.ylim([18, 40])
plt.xlim([6.8,8.2])
plt.title("Number of occurences of precise chemical environnments \n(temperature and pH)")
plt.xlabel("pH")
plt.ylabel("température [°C]")
# Out:
# pH: <FloatingArray>
# [<NA>, 7.5, 7.4, 7.6, 7.8, 8.0, 7.0, 5.5, 7.2, 7.1, 6.8, 8.4]
# Length: 12, dtype: Float64
# Temperatures: <FloatingArray>
# [<NA>, 20.0, 25.0, 22.0, 30.0, 4.0, 23.0, 37.0, 27.0, 28.0]
# Length: 10, dtype: Float64
# Text(0, 0.5, 'température [°C]')

# %%
custom_palette = {
    "Without DrugBank Drug": "royalblue",
    "With DrugBank Drug": "orange",
}

temperatures = list(range(19, 30))
pH = [7.4, 7.5]
col = "ic50"

data = filtered_df[
    (filtered_df[col].notna()) &
    (filtered_df["ph"].isin(pH)) &
    (filtered_df["temp"].isin(temperatures))
].drop_duplicates()

counts = data.groupby(["target_name", "drugbank_drug_name_present"]).size().unstack(fill_value=0)
valid_targets = counts[
    (counts["Without DrugBank Drug"] >= BOXPLOT_MINIMUM_COUNT) & (counts["With DrugBank Drug"] >= BOXPLOT_MINIMUM_COUNT)
].index
filtered_data = data[data["target_name"].isin(valid_targets)]

if not filtered_data.empty:
    plt.figure(figsize=(8, 8))
    sns.boxplot(
        data=filtered_data,
        x="target_name",
        y=col,
        hue="drugbank_drug_name_present",
        palette=custom_palette
    )
    
    plt.yscale("log")
    
    plt.xticks(rotation=45)
    
    plt.title(f"{col} at {temperatures[0]}-{temperatures[-1]}°C and {pH[0]}-{pH[-1]} pH", fontsize=14)
    plt.ylabel(f"{col} (log scale)", fontsize=12)
    plt.xlabel("", rotation=30)
    plt.legend(title="")
    plt.grid(axis="y")
    
    plt.show()
else:
    print("No valid data available for the plot.")

# %% [markdown]
# ## Bootstrapping

# %%
from Chemical_analysis import bootstrap, bootstrap_chemical_param

# select column of interest (ec50, ic50, kd, ki)
col = "ic50"

# Perform bootstrapping
chem_prop_df = bootstrap_chemical_param(filtered_df, column=col)

# plot the result
fig, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(
    data=chem_prop_df, 
    x="target_name",
    y=col,
    hue="drugbank_drug_name_present"
)

# Customize the plot
plt.yscale("log")
plt.xticks(rotation=90)
plt.title(f"{col.upper()} values by Protein and DrugBank Drug Presence (Balanced Data)", fontsize=16)
plt.xlabel("Protein Name", fontsize=14)
plt.ylabel(f"{col.upper()} (log scale)", fontsize=14)
plt.legend(title="DrugBank Drug Presence", fontsize=12)
plt.tight_layout()
plt.grid("y")
plt.show()
# Out:
# c:\Users\godenzi\Documents\ADA\ada-2024-project-hyperbabbage\Chemical_analysis.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return bootstrap_df

# %%
from scipy.stats import mannwhitneyu


# Define a function to perform Mann-Whitney U test on grouped data
def mannwhitney_test(group, col):
    # Split data into two groups based on 'drugbank_drug_name_present'
    without_drug = group[group["drugbank_drug_name_present"] == "Without DrugBank Drug"][col].values
    with_drug = group[group["drugbank_drug_name_present"] == "With DrugBank Drug"][col].values
    
    # Ensure there are at least one sample in both groups
    if len(without_drug) > 0 and len(with_drug) > 0:
        u_stat, p_value = mannwhitneyu(without_drug, with_drug, alternative='two-sided')
    else:
        u_stat, p_value = np.nan, np.nan  # Handle cases with insufficient data
    
    return pd.Series({"u_stat": u_stat, "p_value": p_value})

# Apply the Mann-Whitney test to each group with a specified column
results = chem_prop_df.groupby("target_name").apply(lambda group: mannwhitney_test(group, col)).reset_index()


results
# Out:
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_5344\2722747332.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   results = chem_prop_df.groupby("target_name").apply(lambda group: mannwhitney_test(group, col)).reset_index()
#                                       target_name   u_stat       p_value
# 0                          Adenosine receptor A2a     14.0  3.899684e-34
# 1                             Cytochrome P450 1A2    153.0  2.370662e-32
# 2                            Cytochrome P450 2C19      4.0  2.889194e-34
# 3                             Cytochrome P450 2C9     10.0  3.459069e-34
# 4                             Cytochrome P450 2D6   1920.0  5.295645e-14
# 5                             Cytochrome P450 3A4     58.0  1.449043e-33
# 6                Epidermal growth factor receptor  10000.0  2.562144e-34
# 7                    Prostaglandin G/H synthase 1  10000.0  2.562144e-34
# 8                    Prostaglandin G/H synthase 2  10000.0  2.562144e-34
# 9      Proto-oncogene tyrosine-protein kinase Src   1164.0  7.142897e-21
# 10  Vascular endothelial growth factor receptor 2  10000.0  2.562144e-34

# %% [markdown]
# ### Analyzing non-drug lignads

# %%
without_drug_df = filtered_df[filtered_df["drugbank_drug_name_present"] == "Without DrugBank Drug"]
without_drug_df_Vascular = without_drug_df[without_drug_df["target_name"]=='Adenosine receptor A2a'].dropna(how="all")
ligand_list = without_drug_df_Vascular["ligand_name"].unique()
ligand_list

filtered_subset = filtered_df[filtered_df["ligand_name"].isin(ligand_list)]

non_drug_ligand_without_Vas = filtered_subset[filtered_subset["target_name"] != "Vascular endothelial growth factor receptor 2"]

non_drug_ligand_without_Vas[col].median()
#without_drug_df_Vascular["ki"].median()
# Out:
# 34.6

# %%
bs_non_drug = chem_prop_df[chem_prop_df["drugbank_drug_name_present"]=="Without DrugBank Drug"]
bs_vas = bs_non_drug[bs_non_drug["target_name"]=='Adenosine receptor A2a']

bs_vas[col].median()
# Out:
# 405.4120429982363

# %% [markdown]
# ## Overall comparisons

# %%
Drug_df = filtered_df[filtered_df.drugbank_drug_name_present=='With DrugBank Drug']
Drug_df

drug_protein = Drug_df.groupby("target_name")[["ki", "kd", "ic50", "ec50"]].median()
drug_protein
# Out:
#                                                     ki       kd     ic50  \
# target_name
# Adenosine receptor A2a                           401.0     23.5     87.0
# Cytochrome P450 1A2                            12000.0     <NA>  24400.0
# Cytochrome P450 2C19                            5100.0     <NA>  20900.0
# Cytochrome P450 2C9                             5800.0     <NA>  19500.0
# Cytochrome P450 2D6                              960.0     <NA>  13115.0
# Cytochrome P450 3A4                             4700.0    900.0  10000.0
# Epidermal growth factor receptor                  14.0  10000.0     23.0
# Prostaglandin G/H synthase 1                    5700.0  25900.0   6800.0
# Prostaglandin G/H synthase 2                    1700.0  50.0365    490.0
# Proto-oncogene tyrosine-protein kinase Src      6665.0   2800.0    100.0
# Vascular endothelial growth factor receptor 2     5.35   3200.0     37.0
#
#                                                    ec50
# target_name
# Adenosine receptor A2a                           5012.0
# Cytochrome P450 1A2                            100000.0
# Cytochrome P450 2C19                           100000.0
# Cytochrome P450 2C9                            100000.0
# Cytochrome P450 2D6                            100000.0
# Cytochrome P450 3A4                             22950.0
# Epidermal growth factor receptor                  286.0
# Prostaglandin G/H synthase 1                       <NA>
# Prostaglandin G/H synthase 2                       <NA>
# Proto-oncogene tyrosine-protein kinase Src       1000.0
# Vascular endothelial growth factor receptor 2     273.0

# %%
no_drug_df = filtered_df[filtered_df.drugbank_drug_name_present=="Without DrugBank Drug"]
no_drug_df

no_drug_protein = no_drug_df.groupby("target_name")[["ki", "kd", "ic50", "ec50"]].median()
no_drug_protein
# Out:
#                                                     ki      kd     ic50  \
# target_name
# Adenosine receptor A2a                           192.0   560.0     30.0
# Cytochrome P450 1A2                             1010.0    <NA>  10000.0
# Cytochrome P450 2C19                             925.0    <NA>  10000.0
# Cytochrome P450 2C9                             6000.0    <NA>  10000.0
# Cytochrome P450 2D6                             2800.0    <NA>  11000.0
# Cytochrome P450 3A4                             5745.0  1600.0  10000.0
# Epidermal growth factor receptor                 117.0  1900.0    250.0
# Prostaglandin G/H synthase 1                   10000.0  1040.0  20000.0
# Prostaglandin G/H synthase 2                    2600.0    50.0   1090.0
# Proto-oncogene tyrosine-protein kinase Src      1320.0   340.0    466.5
# Vascular endothelial growth factor receptor 2     98.0  2500.0    260.0
#
#                                                    ec50
# target_name
# Adenosine receptor A2a                            529.0
# Cytochrome P450 1A2                             50000.0
# Cytochrome P450 2C19                            38000.0
# Cytochrome P450 2C9                            25118.86
# Cytochrome P450 2D6                             50000.0
# Cytochrome P450 3A4                             30000.0
# Epidermal growth factor receptor                  278.5
# Prostaglandin G/H synthase 1                    10000.0
# Prostaglandin G/H synthase 2                     5165.0
# Proto-oncogene tyrosine-protein kinase Src       1000.0
# Vascular endothelial growth factor receptor 2      34.0

# %%
comparing_drugs_no_drugs = no_drug_protein > drug_protein
comparing_drugs_no_drugs.sum(axis=0)
# Out:
# ki      7
# kd      2
# ic50    5
# ec50    1
# dtype: Int32

# %% [markdown]
# # Cancer processes

# %%
# joins all targeted proteins 
pattern_protein_names = '|'.join(rf"\b{re.escape(term)}\b" for term in cancer_proteins)
pattern_gene_names =  '|'.join(rf"\b{re.escape(term)}\b" for term in genes_uniprot)
pattern_highly_studied =  '|'.join(rf"\b{re.escape(term)}\b" for term in highly_studied_proteins)

#test
#pattern_protein_names

# extract rows based on the columns that contain cancer_keywords 
all_cancer_molec_df = merged_df[
    #merged_df['drugbank_drug_unii'].str.contains(pattern_protein_names, case=False, na=False) |
    #merged_df['swissprot_target_chain_name'].str.contains(pattern_protein_names, case=False, na=False) |
    merged_df['swissprot_protein_id'].str.contains(pattern_gene_names, case=False, na=False) |
    merged_df['drugbank_protein_name'].str.contains(pattern_protein_names, case=False, na=False)|
    merged_df['target_name'].str.contains(pattern_highly_studied, case=False, na=False)
    #merged_df['target_name'].isin(highly_studied_proteins)
]
all_cancer_molec_df.reset_index(inplace=True)


print(all_cancer_molec_df.shape)
all_cancer_molec_df.head()
# Out:
# (141527, 39)
#    index    ki    ph  temp     ic50  ec50    kd   kon  koff  \
# 0    142  <NA>  <NA>  <NA>  50000.0  <NA>  <NA>  <NA>  <NA>
# 1   3775  <NA>   7.5  20.0    800.0  <NA>  <NA>  <NA>  <NA>
# 2   3776  <NA>   7.5  20.0    220.0  <NA>  <NA>  <NA>  <NA>
# 3   3777  <NA>   7.5  20.0    160.0  <NA>  <NA>  <NA>  <NA>
# 4   3778  <NA>   7.5  20.0     58.0  <NA>  <NA>  <NA>  <NA>
#
#                  doi  ... drugbank_drug_class_superclass  \
# 0               <NA>  ...                            NaN
# 1  10.1021/jm970124v  ...                            NaN
# 2  10.1021/jm970124v  ...                            NaN
# 3  10.1021/jm970124v  ...                            NaN
# 4  10.1021/jm970124v  ...                            NaN
#
#   drugbank_drug_synonyms  drugbank_drug_categories  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
#
#    drugbank_drug_patent_approved drugbank_drug_interaction Matched_On  \
# 0                            NaN                       NaN        NaN
# 1                            NaN                       NaN        NaN
# 2                            NaN                       NaN        NaN
# 3                            NaN                       NaN        NaN
# 4                            NaN                       NaN        NaN
#
#   drugbank_protein_name drugbank_protein_general_function  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   drugbank_protein_specific_function drugbank_protein_organism
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Merging dataframes

# %%
df = pd.merge(all_cancer_molec_df, protein_classes, left_on ="drugbank_protein_name", right_on="Gene", how="left")
for col in df.columns:
    print(col)
# Out:
# index
# ki
# ph
# temp
# ic50
# ec50
# kd
# kon
# koff
# doi
# target_name
# ligand_name
# pubchem_cid
# chebi_id
# chembl_id
# drugbank_id
# kegg_id
# zinc_id
# smiles
# inchi_key
# bindingdb_id
# swissprot_target_chain_name
# swissprot_target_chain_entry_name
# swissprot_protein_id
# Unique_ID
# drugbank_drug_name
# drugbank_drug_unii
# drugbank_drug_toxicity
# drugbank_drug_class_kingdom
# drugbank_drug_class_superclass
# drugbank_drug_synonyms
# drugbank_drug_categories
# drugbank_drug_patent_approved
# drugbank_drug_interaction
# Matched_On
# drugbank_protein_name
# drugbank_protein_general_function
# drugbank_protein_specific_function
# drugbank_protein_organism
# Gene
# Gene synonym
# Ensembl
# Gene description
# Uniprot
# Chromosome
# Position
# Protein class
# Biological process
# Molecular function
# Disease involvement
# Evidence
# HPA evidence
# UniProt evidence
# NeXtProt evidence
# RNA tissue specificity
# RNA tissue distribution
# RNA tissue specificity score
# RNA tissue specific nTPM
# RNA single cell type specificity
# RNA single cell type distribution
# RNA single cell type specificity score
# RNA single cell type specific nTPM
# RNA single nuclei brain specificity
# RNA single nuclei brain distribution
# RNA single nuclei brain specificity score
# RNA single nuclei brain specific nTPM
# RNA cancer specificity
# RNA cancer distribution
# RNA cancer specificity score
# RNA cancer specific FPKM
# RNA brain regional specificity
# RNA brain regional distribution
# RNA brain regional specificity score
# RNA brain regional specific nTPM
# RNA blood cell specificity
# RNA blood cell distribution
# RNA blood cell specificity score
# RNA blood cell specific nTPM
# RNA blood lineage specificity
# RNA blood lineage distribution
# RNA blood lineage specificity score
# RNA blood lineage specific nTPM
# RNA cell line specificity
# RNA cell line distribution
# RNA cell line specificity score
# RNA cell line specific nTPM
# RNA tissue cell type enrichment
# RNA mouse brain regional specificity
# RNA mouse brain regional distribution
# RNA mouse brain regional specificity score
# RNA mouse brain regional specific nTPM
# RNA pig brain regional specificity
# RNA pig brain regional distribution
# RNA pig brain regional specificity score
# RNA pig brain regional specific nTPM
# Antibody
# Reliability (IH)
# Reliability (Mouse Brain)
# Reliability (IF)
# Subcellular location
# Secretome location
# Secretome function
# CCD Protein
# CCD Transcript
# Blood concentration - Conc. blood IM [pg/L]
# Blood concentration - Conc. blood MS [pg/L]
# Blood expression cluster
# Tissue expression cluster
# Brain expression cluster
# Cell line expression cluster
# Single cell expression cluster
# Interactions
# Subcellular main location
# Subcellular additional location
# Antibody RRID
# Cancer prognostics - Bladder Urothelial Carcinoma (TCGA)
# Cancer prognostics - Breast Invasive Carcinoma (TCGA)
# Cancer prognostics - Breast Invasive Carcinoma (validation)
# Cancer prognostics - Cervical Squamous Cell Carcinoma and Endocervical Adenocarcinoma (TCGA)
# Cancer prognostics - Colon Adenocarcinoma (TCGA)
# Cancer prognostics - Colon Adenocarcinoma (validation)
# Cancer prognostics - Glioblastoma Multiforme (TCGA)
# Cancer prognostics - Glioblastoma Multiforme (validation)
# Cancer prognostics - Head and Neck Squamous Cell Carcinoma (TCGA)
# Cancer prognostics - Kidney Chromophobe (TCGA)
# Cancer prognostics - Kidney Renal Clear Cell Carcinoma (TCGA)
# Cancer prognostics - Kidney Renal Clear Cell Carcinoma (validation)
# Cancer prognostics - Kidney Renal Papillary Cell Carcinoma (TCGA)
# Cancer prognostics - Liver Hepatocellular Carcinoma (TCGA)
# Cancer prognostics - Liver Hepatocellular Carcinoma (validation)
# Cancer prognostics - Lung Adenocarcinoma (TCGA)
# Cancer prognostics - Lung Adenocarcinoma (validation)
# Cancer prognostics - Lung Squamous Cell Carcinoma (TCGA)
# Cancer prognostics - Lung Squamous Cell Carcinoma (validation)
# Cancer prognostics - Ovary Serous Cystadenocarcinoma (TCGA)
# Cancer prognostics - Ovary Serous Cystadenocarcinoma (validation)
# Cancer prognostics - Pancreatic Adenocarcinoma (TCGA)
# Cancer prognostics - Pancreatic Adenocarcinoma (validation)
# Cancer prognostics - Prostate Adenocarcinoma (TCGA)
# Cancer prognostics - Rectum Adenocarcinoma (TCGA)
# Cancer prognostics - Rectum Adenocarcinoma (validation)
# Cancer prognostics - Skin Cuteneous Melanoma (TCGA)
# Cancer prognostics - Stomach Adenocarcinoma (TCGA)
# Cancer prognostics - Testicular Germ Cell Tumor (TCGA)
# Cancer prognostics - Thyroid Carcinoma (TCGA)
# Cancer prognostics - Uterine Corpus Endometrial Carcinoma (TCGA)

# %% [markdown]
# ### Plots

# %%
drug_biological_process = df[df["drugbank_drug_name"].notna()].groupby("Biological process")[["drugbank_drug_name"]].count().reset_index()
drug_biological_process
# Out:
#                                    Biological process  drugbank_drug_name
# 0   Adaptive immunity, Apoptosis, Immunity, Innate...                   2
# 1        Adaptive immunity, Immunity, Innate immunity                  64
# 2   Angiogenesis, Differentiation, Host-virus inte...                   2
# 3   Angiogenesis, Differentiation, Host-virus inte...                  16
# 4        Angiogenesis, Lipid metabolism, Phagocytosis                  65
# 5                                           Apoptosis                   7
# 6   Apoptosis, Autophagy, Cell adhesion, DNA damag...                   1
# 7   Apoptosis, Biological rhythms, Cell cycle, Hos...                   1
# 8   Apoptosis, Carbohydrate metabolism, Glucose me...                   6
# 9   Autophagy, Cell adhesion, Endocytosis, Lipid m...                  37
# 10                                 Biological rhythms                   1
# 11                                      Cell adhesion                   6
# 12  Cell cycle, Cell division, DNA damage, Transcr...                 134
# 13         Cell cycle, Cell division, Differentiation                  19
# 14                                         Chemotaxis                   1
# 15                 Chemotaxis, Host-virus interaction                   9
# 16        Glyoxylate bypass, Tricarboxylic acid cycle                   4
# 17                             Host-virus interaction                  99
# 18            Host-virus interaction, Stress response                  75
# 19                                Purine biosynthesis                   2
# 20                                    Stress response                   2

# %%
# Set figure size
plt.figure(figsize=(14.5, 7))

# sorting value
drug_biological_process = drug_biological_process.sort_values(by="drugbank_drug_name", ascending=False)

# Create the barplot
ax = sns.barplot(
    x="Biological process",
    y="drugbank_drug_name",
    hue="Biological process",
    data=drug_biological_process,
    palette="inferno"
)

# Remove x-tick labels
plt.xticks([])

# Create a custom legend
# Extract unique categories from 'Biological process'
categories = drug_biological_process["Biological process"].unique()
palette = sns.color_palette(n_colors=len(categories), palette="inferno")  # Get the default color palette
legend_handles = [mpatches.Patch(color=palette[i], label=category) for i, category in enumerate(categories)]

# Add the legend with custom colors
plt.legend(
    handles=legend_handles,
    title="Biological Process",
    bbox_to_anchor=(0.0, -0.1), 
    loc='upper left',
    borderaxespad=0.

)

# Customize plot appearance
plt.grid(axis="y", which="both", alpha=0.5)

plt.title(
    "Drugbank Entries by Biological Process",
    fontsize=16,
    fontweight="bold",
    pad=20
)

plt.xlabel("Biological Process", size=15)
plt.ylabel("Drug Occurences", size=15)
#plt.yscale("log")
#plt.tight_layout()

# Show plot
plt.show()

# %%
# Extract sizes and categories
sizes = drug_biological_process["drugbank_drug_name"].values
categories = drug_biological_process["Biological process"].values

# Calculate total and percentages
total_size = sum(sizes)
percentages = (sizes / total_size) * 100

# Create a new DataFrame with aggregated "Others"
data = pd.DataFrame({"Biological process": categories, "sizes": sizes, "percentages": percentages})
others = data[data["percentages"] < 1].sum()  # Sum small categories into "Others"
data = data[data["percentages"] >= 1]  # Keep large categories
if not others.empty:
    data = pd.concat([data, pd.DataFrame({"Biological process": ["Others"], "sizes": [others["sizes"]], "percentages": [others["percentages"]]})])

# Generate a color palette for the updated categories
categories = data["Biological process"].values
sizes = data["sizes"].values
palette = sns.color_palette("inferno", n_colors=len(categories))
colors = [palette[i] for i in range(len(categories))]

# Create the pie chart
plt.figure(figsize=(10, 8))
wedges, texts, autotexts = plt.pie(
    sizes,
    labels=None,  # Remove default labels
    colors=colors,
    autopct='%1.1f%%',  # Percentage values
    startangle=0,
    wedgeprops={"edgecolor": "black", "linewidth": 0.3},
    pctdistance=1.1,  # Position percentages outside the pie
    textprops={'fontsize': 10}
)

# Remove the center to create a donut chart with a black edge
center_circle = Circle((0, 0), 0.60, color='white', edgecolor='black', linewidth=1.5)
plt.gca().add_artist(center_circle)

# Add custom legend below the chart
legend_handles = [mpatches.Patch(color=colors[i], label=categories[i]) for i in range(len(categories))]
plt.legend(
    handles=legend_handles,
    title="Biological Process",
    bbox_to_anchor=(0.5, -0.3),  # Position legend below the chart
    loc='center',
    borderaxespad=0.,
    fontsize=10,
    title_fontsize=12,
    ncol=1  # Arrange legend entries into two columns
)

# Add a visually distinct title
plt.title(
    "Proportion of Drugbank Entries by Biological Process",
    fontsize=16,
    fontweight="bold",
    pad=20
)

# Optimize layout for neatness
#plt.tight_layout()

# Display the chart
plt.show()
# Out:
# C:\Users\godenzi\AppData\Local\Temp\ipykernel_18284\2489664596.py:42: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   center_circle = Circle((0, 0), 0.60, color='white', edgecolor='black', linewidth=1.5)
