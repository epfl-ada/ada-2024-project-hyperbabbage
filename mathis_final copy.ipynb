# %% [markdown]
# # Requires to have in 'data/clean/' the data : 'merged_dataframe.pkl' & 'ligands_related_to_cancer_proteins.pkl'

# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import re

# %% [markdown]
# ### Import clean datasets

# %%
df = pd.read_pickle('data/clean/merged_dataframe.pkl')
cancer_df = pd.read_pickle('data/clean/ligands_related_to_cancer_proteins.pkl')

# %% [markdown]
# ### Keep only the ones matched with Drugbank to have the toxicity reports

# %%
df_matched = df[df['Matched_On'].isna() == False]
cancer_df_matched = cancer_df[cancer_df['Matched_On'].isna() == False]

# %% [markdown]
# ### Find the drugs linked to our 11 most studied cancer related proteins

# %%
highly_studied_proteins = ['Cytochrome P450 3A4', 'Epidermal growth factor receptor', 'Proto-oncogene tyrosine-protein kinase Src', 'Vascular endothelial growth factor receptor 2', 'Adenosine receptor A2a', 'Cytochrome P450 2C9', 'Cytochrome P450 1A2', 'Cytochrome P450 2C19', 'Cytochrome P450 2D6', 'Prostaglandin G/H synthase 1', 'Prostaglandin G/H synthase 2']
# joins all targeted proteins
pattern_highly_studied =  '|'.join(rf"\b{re.escape(term)}\b" for term in highly_studied_proteins)

# extract rows based on the columns that contain highly_studied_proteins 
filtered_df_highly_studied = df_matched[df_matched['target_name'].str.contains(pattern_highly_studied, case=False, na=False)]
filtered_df_highly_studied.reset_index(inplace=True)

cancer_most_studied_drugs = filtered_df_highly_studied.drugbank_drug_name.unique()

# rows from df_matched that have a drugbank_drug_name that is in cancer_most_studied_drugs
cancer_most_studied_df = df_matched[df_matched['drugbank_drug_name'].isin(cancer_most_studied_drugs)]

# %%
len()

# %% [markdown]
# # Grouping by drug
# The columns for this are :
# - the number of entries for that drug
# - the number rows that have an approved patent
# - the unique toxicity reports
# - the InChI keys
# - the ligand names
# - the number of proteins per drug
# - the number of ligand per drug
# - the list of unique toxicity reports per drug
# - the number of different toxicity reports

# %% [markdown]
# #### For all of merged BDB/DrugBank

# %%
grouped_df = df_matched.groupby("drugbank_drug_name").agg({
    "drugbank_drug_name": "count",
    "drugbank_drug_patent_approved": lambda x: x.notna().sum(),
    "drugbank_drug_toxicity": lambda x: x.unique(),
    "inchi_key" : lambda x: x.unique(),
    "ligand_name" : lambda x: x.unique()
}).rename(columns={"drugbank_drug_name": "count"}).sort_values(by="count", ascending=False)

grouped_df["num_prot_per_drug"] = grouped_df["inchi_key"].apply(lambda x: len(x))
grouped_df["num_lig_per_drug"] = grouped_df["ligand_name"].apply(lambda x: len(x))
grouped_df["unique_toxicity"] = grouped_df["drugbank_drug_toxicity"].apply(lambda x: x[0] )
grouped_df["num_diff_toxicity"] = grouped_df["drugbank_drug_toxicity"].apply(lambda x: len(x) )

grouped_df.head()
# Out:
#                     count  drugbank_drug_patent_approved  \
# drugbank_drug_name
# Staurosporine        2369                              0
# Acetazolamide        2344                              0
# Vorinostat           1736                           1736
# Sunitinib            1692                           1692
# Sorafenib            1660                           1660
#
#                                                drugbank_drug_toxicity  \
# drugbank_drug_name
# Staurosporine                                                   [nan]
# Acetazolamide                                                   [nan]
# Vorinostat                                                      [nan]
# Sunitinib           [The maximally tolerated dose for rat, mouse, ...
# Sorafenib           [The oral lowest published toxic dose (Toxic D...
#
#                                                             inchi_key  \
# drugbank_drug_name
# Staurosporine       [HKSZLNNOFSGOKW-FYTWVXJKSA-N, HKSZLNNOFSGOKW-U...
# Acetazolamide                           [BZKPWHYZMXOIDC-UHFFFAOYSA-N]
# Vorinostat                              [WAEXFXRVDQXREF-UHFFFAOYSA-N]
# Sunitinib                               [WINHZLLDWRZWRT-ATVHPVEESA-N]
# Sorafenib                               [MLDQJTXFUGDVEO-UHFFFAOYSA-N]
#
#                                                           ligand_name  \
# drugbank_drug_name
# Staurosporine       [(2S,3R,4R,6R)-3-methoxy-2-methyl-4-(methylami...
# Acetazolamide       [AZA::AZA2::AZM acetazolamide::Acerazolamide, ...
# Vorinostat          [CHEMBL98::N-hydroxy-N'-phenyloctanediamide::S...
# Sunitinib           [CHEMBL535::N-[2-(diethylamino)ethyl]-5-[(Z)-(...
# Sorafenib           [4-[4-({[4-chloro-3-(trifluoromethyl)phenyl]ca...
#
#                     num_prot_per_drug  num_lig_per_drug  \
# drugbank_drug_name
# Staurosporine                       2                 4
# Acetazolamide                       1                 1
# Vorinostat                          1                 1
# Sunitinib                           1                 2
# Sorafenib                           1                 2
#
#                                                       unique_toxicity  \
# drugbank_drug_name
# Staurosporine                                                     NaN
# Acetazolamide                                                     NaN
# Vorinostat                                                        NaN
# Sunitinib           The maximally tolerated dose for rat, mouse, a...
# Sorafenib           The oral lowest published toxic dose (Toxic Do...
#
#                     num_diff_toxicity
# drugbank_drug_name
# Staurosporine                       1
# Acetazolamide                       1
# Vorinostat                          1
# Sunitinib                           1
# Sorafenib                           1

# %% [markdown]
# ### For our extended most studied cancer proteins

# %%
grouped_df_studied = cancer_most_studied_df.groupby("drugbank_drug_name").agg({
    "drugbank_drug_name": "count",
    "drugbank_drug_patent_approved": lambda x: x.notna().sum(),
    "drugbank_drug_toxicity": lambda x: x.unique(),
    "inchi_key" : lambda x: x.unique(),
    "ligand_name" : lambda x: x.unique()
}).rename(columns={"drugbank_drug_name": "count"}).sort_values(by="count", ascending=False)

grouped_df_studied["num_prot_per_drug"] = grouped_df_studied["inchi_key"].apply(lambda x: len(x))
grouped_df_studied["num_lig_per_drug"] = grouped_df_studied["ligand_name"].apply(lambda x: len(x))

grouped_df_studied["unique_toxicity"] = grouped_df_studied["drugbank_drug_toxicity"].apply(lambda x: x[0] )
grouped_df_studied["num_diff_toxicity"] = grouped_df_studied["drugbank_drug_toxicity"].apply(lambda x: len(x) )

# %%
print("Total number of drugs :                  ",len(grouped_df))
print("Number of drugs with a toxicity report : ",sum(grouped_df["unique_toxicity"].isna() == False)) 
print("Number of unique toxicity reports :      ",len(grouped_df["unique_toxicity"].unique()))
# Out:
# Total number of drugs :                   5716
# Number of drugs with a toxicity report :  1410
# Number of unique toxicity reports :       1397

# %% [markdown]
# # Toxicity score

# %%
# Making a large string of all toxicity reports text
unique_toxicity_values = " ".join(grouped_df["unique_toxicity"].unique().astype(str))

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(unique_toxicity_values)

# %%
# Count the occurances of each word in that sting
words = [token.text for token in doc]

# five most common tokens
word_freq = Counter(words)
common_words = word_freq.most_common(5)

print(common_words)
# Out:
# [(',', 9840), ('of', 4577), ('.', 4334), ('and', 4304), ('in', 3832)]

# %%
# drop punctuation and stop words
words = [token.text for token in doc if token.is_stop != True and token.is_punct != True]

# most common tokens
word_freq = Counter(words)
common_words = word_freq.most_common(1000000)

common_words
# Out:
# [('mg', 1779),
#  ('kg', 1511),
#  ('\r\n\r\n', 1211),
#  ('overdose', 1003),
#  ('>', 719),
#  ('rats', 693),
#  ('dose', 680),
#  ('effects', 647),
#  ('<', 611),
#  ('patients', 560),
#  ('oral', 559),
#  ('doses', 547),
#  ('LD', 538),
#  ('include', 507),
#  ('sub>50</sub', 460),
#  ('studies', 456),
#  ('adverse', 447),
#  ('day', 415),
#  ('human', 412),
#  ('times', 400),
#  ('mice', 367),
#  ('toxicity', 361),
#  ('reported', 351),
#  ('LD50', 348),
#  ('recommended', 339),
#  ('FDA', 339),
#  ('drug', 319),
#  ('nausea', 309),
#  ('symptoms', 304),
#  ('rat', 298),
#  ('supportive', 295),
#  ('use', 286),
#  ('risk', 282),
#  ('vomiting', 273),
#  ('Oral', 269),
#  ('observed', 263),
#  ('Label', 261),
#  ('increased', 254),
#  ('clinical', 247),
#  ('treatment', 242),
#  (' ', 236),
#  ('hypotension', 232),
#  ('administration', 224),
#  ('associated', 222),
#  ('Symptoms', 219),
#  ('mouse', 215),
#  ('severe', 213),
#  ('including', 211),
#  ('\r\n', 207),
#  ('renal', 204),
#  ('overdosage', 203),
#  ('potential', 201),
#  ('administered', 196),
#  ('reactions', 192),
#  ('pregnancy', 189),
#  ('label', 187),
#  ('pain', 185),
#  ('fertility', 182),
#  ('fetal', 179),
#  ('pregnant', 179),
#  ('study', 178),
#  ('case', 177),
#  ('cases', 168),
#  ('2', 168),
#  ('exposure', 167),
#  ('depression', 165),
#  ('male', 164),
#  ('Patients', 162),
#  ('dizziness', 162),
#  ('acute', 161),
#  ('respiratory', 160),
#  ('treated', 159),
#  ('blood', 159),
#  ('following', 159),
#  ('assay', 157),
#  ('diarrhea', 156),
#  ('headache', 156),
#  ('cause', 154),
#  ('symptomatic', 151),
#  ('information', 150),
#  ('female', 150),
#  ('vitro', 150),
#  ('patient', 150),
#  ('maximum', 149),
#  ('cardiac', 149),
#  ('decreased', 144),
#  ('given', 142),
#  ('occur', 140),
#  ('high', 137),
#  ('data', 136),
#  ('gastrointestinal', 135),
#  ('increase', 135),
#  ('women', 134),
#  ('measures', 134),
#  ('10', 133),
#  ('effect', 130),
#  ('based', 128),
#  ('approximately', 127),
#  ('humans', 126),
#  ('coma', 126),
#  ('intravenous', 126),
#  ('signs', 125),
#  ('daily', 121),
#  ('available', 121),
#  ('milk', 118),
#  ('known', 115),
#  ('animal', 114),
#  ('1', 113),
#  ('respectively', 112),
#  ('abdominal', 112),
#  ('lead', 112),
#  ('Overdose', 111),
#  ('significant', 108),
#  ('higher', 108),
#  ('mutagenic', 108),
#  ('present', 107),
#  ('drowsiness', 106),
#  ('5', 106),
#  ('3', 105),
#  ('levels', 105),
#  ('therapy', 104),
#  ('vivo', 104),
#  ('experiencing', 104),
#  ('6', 103),
#  ('failure', 103),
#  ('convulsions', 103),
#  ('result', 102),
#  ('common', 101),
#  ('AUC', 101),
#  ('skin', 101),
#  ('MRHD', 101),
#  ('limited', 101),
#  ('tachycardia', 101),
#  ('greater', 98),
#  ('bradycardia', 98),
#  ('=', 98),
#  ('loss', 97),
#  ('days', 96),
#  ('seizures', 96),
#  ('liver', 94),
#  ('found', 94),
#  ('single', 93),
#  ('impairment', 93),
#  ('related', 93),
#  ('evidence', 92),
#  ('death', 92),
#  ('monitoring', 91),
#  ('rabbits', 90),
#  ('orally', 89),
#  ('body', 88),
#  ('events', 88),
#  ('CNS', 87),
#  ('muscle', 86),
#  ('antidote', 86),
#  ('shown', 86),
#  ('g', 86),
#  ('toxic', 85),
#  ('reproductive', 85),
#  ('function', 85),
#  ('confusion', 85),
#  ('plasma', 85),
#  ('maternal', 84),
#  ('reports', 84),
#  ('carcinogenicity', 83),
#  ('likely', 83),
#  ('micronucleus', 82),
#  ('seen', 81),
#  ('cell', 81),
#  ('development', 81),
#  ('nursing', 81),
#  ('4', 80),
#  ('low', 80),
#  ('heart', 80),
#  ('system', 79),
#  ('specific', 79),
#  ('acid', 79),
#  ('fatigue', 78),
#  ('test', 78),
#  ('cardiovascular', 78),
#  ('drugs', 78),
#  ('weight', 78),
#  ('incidence', 78),
#  ('trials', 77),
#  ('hypertension', 77),
#  ('years', 77),
#  ('50', 76),
#  ('30', 76),
#  ('overdoses', 76),
#  ('expected', 76),
#  ('Ames', 75),
#  ('experience', 75),
#  ('100', 74),
#  ('hepatic', 74),
#  ('pressure', 74),
#  ('and/or', 74),
#  ('carcinogenic', 73),
#  ('20', 72),
#  ('ingestion', 72),
#  ('somnolence', 72),
#  ('mouth', 72),
#  ('resulted', 71),
#  ('females', 69),
#  ('gastric', 69),
#  ('weeks', 68),
#  ('occurred', 68),
#  ('hours', 68),
#  ('mutation', 67),
#  ('hemodialysis', 67),
#  ('rash', 66),
#  ('children', 65),
#  ('exposures', 65),
#  ('safety', 65),
#  ('therapeutic', 65),
#  ('MSDS', 64),
#  ('changes', 64),
#  ('receiving', 64),
#  ('showed', 64),
#  ('performed', 63),
#  ('dry', 63),
#  ('lavage', 63),
#  ('Acute', 62),
#  ('dogs', 62),
#  ('bone', 62),
#  ('cells', 62),
#  ('age', 62),
#  ('considered', 62),
#  ('care', 61),
#  ('monitored', 61),
#  ('general', 61),
#  ('readily', 61),
#  ('nervous', 61),
#  ('syndrome', 61),
#  ('reduced', 60),
#  ('findings', 60),
#  ('bleeding', 60),
#  ('excreted', 60),
#  ('bacterial', 59),
#  ('possible', 59),
#  ('breast', 59),
#  ('mild', 59),
#  ('arrhythmias', 58),
#  ('event', 57),
#  ('embryo', 56),
#  ('weakness', 56),
#  ('concentrations', 56),
#  ('subcutaneous', 56),
#  ('systemic', 56),
#  ('males', 55),
#  ('Use', 55),
#  ('central', 55),
#  ('benefit', 55),
#  ('animals', 54),
#  ('rate', 54),
#  ('serum', 54),
#  ('agitation', 54),
#  ('major', 54),
#  ('15', 53),
#  ('term', 53),
#  ('included', 53),
#  ('period', 53),
#  ('200', 53),
#  ('like', 53),
#  ('hallucinations', 53),
#  ('edema', 52),
#  ('dosage', 52),
#  ('assays', 52),
#  ('insomnia', 52),
#  ('fever', 52),
#  ('non', 51),
#  ('lethal', 51),
#  ('fatal', 51),
#  ('500', 50),
#  ('genotoxic', 50),
#  ('subjects', 50),
#  ('aberration', 50),
#  ('increases', 50),
#  ('compared', 50),
#  ('mating', 49),
#  ('charcoal', 49),
#  ('produce', 49),
#  ('intraperitoneal', 49),
#  ('dialysis', 48),
#  ('activated', 48),
#  ('pediatric', 48),
#  ('2000', 47),
#  ('conducted', 47),
#  ('disease', 47),
#  ('noted', 47),
#  ('tumors', 47),
#  ('marrow', 47),
#  ('reverse', 47),
#  ('management', 47),
#  ('clastogenic', 47),
#  ('lethargy', 47),
#  ('arrest', 47),
#  ('constipation', 47),
#  ('m2', 46),
#  ('appropriate', 46),
#  ('organogenesis', 46),
#  ('protein', 46),
#  ('Signs', 46),
#  ('controlled', 46),
#  ('chromosomal', 46),
#  ('taking', 46),
#  ('tolerated', 45),
#  ('rabbit', 45),
#  ('year', 45),
#  ('harm', 45),
#  ('Data', 45),
#  ('Overdosage', 45),
#  ('surface', 45),
#  ('birth', 45),
#  ('Toxicity', 45),
#  ('ataxia', 45),
#  ('defects', 45),
#  ('metabolic', 44),
#  ('40', 44),
#  ('basis', 44),
#  ('developmental', 44),
#  ('24', 44),
#  ('results', 44),
#  ('e.g.', 44),
#  ('time', 44),
#  ('300', 44),
#  ('1000', 44),
#  ('normal', 44),
#  ('anemia', 43),
#  ('tremor', 43),
#  ('healthy', 43),
#  ('experienced', 43),
#  ('clinically', 43),
#  ('discontinuation', 42),
#  ('chronic', 42),
#  ('tract', 42),
#  ('withdrawal', 42),
#  ('demonstrated', 42),
#  ('addition', 42),
#  ('vision', 42),
#  ('adults', 42),
#  ('elderly', 42),
#  ('infants', 42),
#  ('highest', 42),
#  ('urinary', 41),
#  ('caused', 41),
#  ('reproduction', 41),
#  ('12', 41),
#  ('active', 41),
#  ('response', 41),
#  ('consistent', 41),
#  ('Treatment', 41),
#  ('life', 41),
#  ('occurs', 41),
#  ('combination', 40),
#  ('months', 40),
#  ('mortality', 40),
#  ('flushing', 40),
#  ('similar', 40),
#  ('metabolite', 40),
#  ('placebo', 40),
#  ('irritation', 40),
#  ('mutagenicity', 40),
#  ('8', 40),
#  ('60', 39),
#  ('received', 39),
#  ('collapse', 39),
#  ('control', 39),
#  ('sedation', 39),
#  ('retention', 39),
#  ('consciousness', 39),
#  ('medical', 39),
#  ('necessary', 39),
#  ('abnormal', 39),
#  ('Rat', 39),
#  ('400', 38),
#  ('lower', 38),
#  ('number', 38),
#  ('impaired', 38),
#  ('abnormalities', 38),
#  ('unknown', 38),
#  ('prolonged', 38),
#  ('airway', 38),
#  ('unlikely', 38),
#  ('disturbances', 38),
#  ('\r\n ', 38),
#  ('followed', 38),
#  ('infant', 38),
#  ('especially', 38),
#  ('excessive', 38),
#  ('breathing', 37),
#  ('adequate', 37),
#  ('fetus', 37),
#  ('commonly', 37),
#  ('generally', 37),
#  ('status', 37),
#  ('lactation', 37),
#  ('suppression', 37),
#  ('QT', 37),
#  ('established', 37),
#  ('woman', 37),
#  ('caution', 37),
#  ('negative', 37),
#  ('lymphoma', 36),
#  ('Based', 36),
#  ('induced', 36),
#  ('gestation', 36),
#  ('acidosis', 36),
#  ('electrolyte', 36),
#  ('TDLO', 36),
#  ('block', 36),
#  ('18', 36),
#  ('usually', 36),
#  ('injection', 36),
#  ('800', 35),
#  ('long', 35),
#  ('level', 35),
#  ('area', 35),
#  ('removed', 35),
#  ('exposed', 35),
#  ('seizure', 35),
#  ('activity', 35),
#  ('effective', 35),
#  ('fold', 35),
#  ('m', 34),
#  ('vital', 34),
#  ('7', 34),
#  ('post', 34),
#  ('interval', 34),
#  ('managed', 34),
#  ('equivalent', 34),
#  ('mcg', 34),
#  ('anorexia', 33),
#  ('tested', 33),
#  ('kidney', 33),
#  ('leading', 33),
#  ('growth', 33),
#  ('multiple', 33),
#  ('respiration', 33),
#  ('risks', 33),
#  ('moderate', 33),
#  ('indicated', 33),
#  ('mothers', 33),
#  ('shock', 33),
#  ('5000', 33),
#  ('values', 33),
#  ('suspected', 32),
#  ('reduction', 32),
#  ('25', 32),
#  ('action', 32),
#  ('emesis', 32),
#  ('peripheral', 32),
#  ('mother', 32),
#  ('difficulty', 32),
#  ('restlessness', 32),
#  ('dermal', 32),
#  ('frequency', 32),
#  ('stomach', 31),
#  ('presence', 31),
#  ('monkeys', 31),
#  ('report', 31),
#  ('mechanism', 31),
#  ('GI', 31),
#  ('damage', 31),
#  ('concentration', 31),
#  ('stimulation', 31),
#  ('sodium', 31),
#  ('prior', 30),
#  ('Carcinogenicity', 30),
#  ('month', 30),
#  ('characterized', 30),
#  ('thrombocytopenia', 30),
#  ('involve', 30),
#  ('atropine', 30),
#  ('produced', 30),
#  ('anxiety', 30),
#  ('clearance', 30),
#  ('blurred', 30),
#  ('Mouse', 30),
#  ('pupils', 30),
#  ('teratogenic', 30),
#  ('breastfeeding', 30),
#  ('L1526', 30),
#  ('twice', 29),
#  ('cramps', 29),
#  ('early', 29),
#  ('local', 29),
#  ('decrease', 29),
#  ('mental', 29),
#  ('younger', 29),
#  ('fluid', 29),
#  ('topical', 29),
#  ('rare', 29),
#  ('required', 29),
#  ('published', 28),
#  ('pulmonary', 28),
#  ('adrenal', 28),
#  ('week', 28),
#  ('infection', 28),
#  ('sup>2</sup', 28),
#  ('closely', 28),
#  ('ventricular', 28),
#  ('outcomes', 28),
#  ('Symptomatic', 28),
#  ('trimester', 28),
#  ('profile', 28),
#  ('hepatotoxicity', 28),
#  ('prolongation', 28),
#  ('initiated', 28),
#  ('resulting', 28),
#  ('malformations', 28),
#  ('remove', 28),
#  ('reversible', 28),
#  ('group', 28),
#  ('small', 27),
#  ('0.3', 27),
#  ('elevated', 27),
#  ('neutropenia', 27),
#  ('delivery', 27),
#  ('ingested', 27),
#  ('state', 27),
#  ('affect', 27),
#  ('large', 27),
#  ('rapid', 27),
#  ('Adverse', 27),
#  ('cough', 27),
#  ('involving', 26),
#  ('equal', 26),
#  ('14', 26),
#  ('pre', 26),
#  ('child', 26),
#  ('hemorrhage', 26),
#  ('atrophy', 26),
#  ('dosing', 26),
#  ('accidental', 26),
#  ('discontinue', 26),
#  ('disorders', 26),
#  ('Intravenous', 26),
#  ('benzodiazepines', 26),
#  ('contact', 26),
#  ('F4349', 26),
#  ('F3925', 26),
#  ('absorption', 25),
#  ('adenomas', 25),
#  ('Chinese', 25),
#  ('hamster', 25),
#  ('activation', 25),
#  ('taken', 25),
#  ('250', 25),
#  ('16', 25),
#  ('Treat', 25),
#  ('face', 25),
#  ('highly', 25),
#  ('advised', 25),
#  ('adult', 25),
#  ('develop', 25),
#  ('ECG', 25),
#  ('effectiveness', 25),
#  ('efficacy', 25),
#  ('value', 25),
#  ('urine', 25),
#  ('Animal', 25),
#  ('fenofibric', 25),
#  ('lowest', 24),
#  ('offspring', 24),
#  ('necrosis', 24),
#  ('sweating', 24),
#  ('Hemodialysis', 24),
#  ('lymphocytes', 24),
#  ('bound', 24),
#  ('implantation', 24),
#  ('injury', 24),
#  ('literature', 24),
#  ('tremors', 24),
#  ('appear', 24),
#  ('irritability', 24),
#  ('beta', 24),
#  ('range', 24),
#  ('second', 24),
#  ('Studies', 24),
#  ('significantly', 24),
#  ('circulatory', 24),
#  ('F3919', 24),
#  ('F3922', 24),
#  ('F4223', 24),
#  ('creatinine', 23),
#  ('Advise', 23),
#  ('possibility', 23),
#  ('extrapyramidal', 23),
#  ('distress', 23),
#  ('pruritus', 23),
#  ('elimination', 23),
#  ('mL', 23),
#  ('upper', 23),
#  ('Effects', 23),
#  ('infusion', 23),
#  ('90', 23),
#  ('vertigo', 23),
#  ('particularly', 23),
#  ('transient', 23),
#  ('treat', 23),
#  ('alcohol', 23),
#  ('65', 23),
#  ('performance', 23),
#  ('chest', 23),
#  ('hypoglycemia', 23),
#  ('benzodiazepine', 23),
#  ('breastfed', 23),
#  ('TDLo', 22),
#  ('mammalian', 22),
#  ('Severe', 22),
#  ('80', 22),
#  ('inhibitors', 22),
#  ('psychosis', 22),
#  ('13', 22),
#  ('skeletal', 22),
#  ('miscarriage', 22),
#  ('studied', 22),
#  ('C', 22),
#  ('provide', 22),
#  ('reaction', 22),
#  ('old', 22),
#  ('fluids', 22),
#  ('note', 22),
#  ('dyspepsia', 22),
#  ('nephrotoxicity', 22),
#  ('Chronic', 22),
#  ('150', 22),
#  ('myocardial', 22),
#  ('limiting', 22),
#  ('F3157', 22),
#  ('agent', 22),
#  ('hypersensitivity', 22),
#  ('SYNDROS', 22),
#  ('agents', 22),
#  ('dog', 21),
#  ('cancer', 21),
#  ('positive', 21),
#  ('tubular', 21),
#  ('duration', 21),
#  ('production', 21),
#  ('detected', 21),
#  ('testicular', 21),
#  ('complications', 21),
#  ('support', 21),
#  ('DNA', 21),
#  ('total', 21),
#  ('75', 21),
#  ('intravenously', 21),
#  ('abuse', 21),
#  ('9', 21),
#  ('half', 21),
#  ('stupor', 21),
#  ('IV', 21),
#  ('Pregnancy', 21),
#  ('Intraperitoneal', 21),
#  ('kg.[MSDS', 21),
#  ('epigastric', 21),
#  ('calcium', 21),
#  ('manifestations', 21),
#  ('older', 21),
#  ('vitamin', 21),
#  ('sperm', 20),
#  ('toxicities', 20),
#  ('consider', 20),
#  ('600', 20),
#  ('delirium', 20),
#  ('asthenia', 20),
#  ('mydriasis', 20),
#  ('NOAEL', 20),
#  ('discontinued', 20),
#  ('short', 20),
#  ('Clinical', 20),
#  ('exercised', 20),
#  ('volunteers', 20),
#  ('ophthalmic', 20),
#  ('anticholinergic', 20),
#  ('threatening', 20),
#  ('paralysis', 20),
#  ('medication', 20),
#  ('genotoxicity', 20),
#  ('disturbance', 20),
#  ('immediately', 20),
#  ('insufficient', 20),
#  ('11', 20),
#  ('zuranolone', 20),
#  ('carcinomas', 19),
#  ('chromosome', 19),
#  ('Fertility', 19),
#  ('hepatocellular', 19),
#  ('degeneration', 19),
#  ('poison', 19),
#  ('excess', 19),
#  ('ventilation', 19),
#  ('evaluated', 19),
#  ('induce', 19),
#  ('combined', 19),
#  ('possibly', 19),
#  ('High', 19),
#  ('rhabdomyolysis', 19),
#  ('venlafaxine', 19),
#  ('dosages', 19),
#  ('close', 19),
#  ('26', 19),
#  ('hyperglycemia', 19),
#  ('determined', 19),
#  ('ranging', 19),
#  ('B', 19),
#  ('administering', 18),
#  ('frequently', 18),
#  ('statistically', 18),
#  ('gland', 18),
#  ('0.5', 18),
#  ('developed', 18),
#  ('tests', 18),
#  ('individuals', 18),
#  ('vasopressors', 18),
#  ('hour', 18),
#  ('dependence', 18),
#  ('hypokalemia', 18),
#  ('adjustment', 18),
#  ('visual', 18),
#  ('reflexes', 18),
#  ('nervousness', 18),
#  ('binding', 18),
#  ('lack', 18),
#  ('dysfunction', 18),
#  ('secondary', 18),
#  ('apnea', 18),
#  ('taste', 18),
#  ('Subcutaneous', 18),
#  ('difference', 18),
#  ('≥', 18),
#  ('breath', 18),
#  ('eye', 18),
#  ('light', 18),
#  ('intoxication', 18),
#  ('benefits', 18),
#  ('aged', 18),
#  ('Mild', 18),
#  ('standard', 18),
#  ('site', 18),
#  ('organs', 17),
#  ('70', 17),
#  ('weights', 17),
#  ('insufficiency', 17),
#  ('\r\n\r\n ', 17),
#  ('clearly', 17),
#  ('feeding', 17),
#  ('severity', 17),
#  ('appetite', 17),
#  ('1.5', 17),
#  ('disorientation', 17),
#  ('palpitations', 17),
#  ('delayed', 17),
#  ('Common', 17),
#  ('deaths', 17),
#  ('epinephrine', 17),
#  ('serotonin', 17),
#  ('Dialysis', 17),
#  ('metabolites', 17),
#  ('180', 17),
#  ('appears', 17),
#  ('malaise', 17),
#  ('immediate', 17),
#  ('potentially', 17),
#  ('heartbeat', 17),
#  ('includes', 17),
#  ('developing', 17),
#  ('maintenance', 17),
#  ('inhaled', 17),
#  ('primary', 17),
#  ('fenofibrate', 17),
#  ('unabsorbed', 17),
#  ('vancomycin', 17),
#  ('lung', 16),
#  ('0.4', 16),
#  ('ovary', 16),
#  ('mutagenesis', 16),
#  ('testes', 16),
#  ('important', 16),
#  ('causes', 16),
#  ('Doses', 16),
#  ('120', 16),
#  ('estimated', 16),
#  ('useful', 16),
#  ('bosutinib', 16),
#  ('dehydration', 16),
#  ('ocular', 16),
#  ('thought', 16),
#  ('altered', 16),
#  ('neuromuscular', 16),
#  ('solution', 16),
#  ('monitor', 16),
#  ('irregular', 16),
#  ('erythema', 16),
#  ('itching', 16),
#  ('burning', 16),
#  ('suggest', 16),
#  ('category', 16),
#  ('grams', 16),
#  ('gain', 16),
#  ('tinnitus', 16),
#  ('dyspnea', 16),
#  ('dilated', 16),
#  ('48', 16),
#  ('neonatal', 16),
#  ('shortness', 16),
#  ('unusual', 16),
#  ('4000', 16),
#  ('volume', 16),
#  ('populations', 16),
#  ('degree', 16),
#  ('typically', 16),
#  ('removal', 16),
#  ('teratogenicity', 16),
#  ('dronabinol', 16),
#  ('repeated', 16),
#  ('hydrochloride', 16),
#  ('avoided', 16),
#  ('bronchospasm', 16),
#  ('L5930', 16),
#  ('tegaserod', 16),
#  ('prescribing', 15),
#  ('interstitial', 15),
#  ('bladder', 15),
#  ('relevance', 15),
#  ('product', 15),
#  ('identified', 15),
#  ('revealed', 15),
#  ('involved', 15),
#  ('according', 15),
#  ('maintain', 15),
#  ('synthesis', 15),
#  ('recovered', 15),
#  ('2.5', 15),
#  ('fetuses', 15),
#  ('pregnancies', 15),
#  ('oxygen', 15),
#  ('hearing', 15),
#  ('movements', 15),
#  ('ABILIFY', 15),
#  ('dietary', 15),
#  ('glucose', 15),
#  ('require', 15),
#  ('vs.', 15),
#  ('Cases', 15),
#  ('arrhythmia', 15),
#  ('nasal', 15),
#  ('documented', 15),
#  ('tissue', 15),
#  ('hyperthermia', 15),
#  ('currently', 15),
#  ('contraception', 15),
#  ('Drug', 15),
#  ('Overdoses', 15),
#  ('geriatric', 15),
#  ('angina', 15),
#  ('decontamination', 15),
#  ('exists', 15),
#  ('hyponatremia', 15),
#  ('Carcinogenesis', 15),
#  ('route', 15),
#  ('RAT', 15),
#  ('750', 15),
#  ('Long', 15),
#  ('formation', 15),
#  ('conduction', 15),
#  ('allergic', 15),
#  ('congenital', 15),
#  ('acetaminophen', 15),
#  ('angiotensin', 15),
#  ('clobazam', 15),
#  ('Dose', 14),
#  ('primarily', 14),
#  ('rates', 14),
#  ('obtained', 14),
#  ('affected', 14),
#  ('embryonic', 14),
#  ('myelosuppression', 14),
#  ('45', 14),
#  ('repeat', 14),
#  ('manage', 14),
#  ('medications', 14),
#  ('Single', 14),
#  ('untreated', 14),
#  ('de', 14),
#  ('accompanied', 14),
#  ('history', 14),
#  ('syncope', 14),
#  ('disorder', 14),
#  ('19', 14),
#  ('physical', 14),
#  ('depressed', 14),
#  ('complex', 14),
#  ('measured', 14),
#  ('balance', 14),
#  ('extreme', 14),
#  ('swelling', 14),
#  ('thyroid', 14),
#  ('Safety', 14),
#  ('Risk', 14),
#  ('amounts', 14),
#  ('Caution', 14),
#  ('brimonidine', 14),
#  ('circulation', 14),
#  ('presented', 14),
#  ('rarely', 14),
#  ('water', 14),
#  ('hypocalcemia', 14),
#  ('diminished', 14),
#  ('late', 14),
#  ('wheezing', 14),
#  ('decreases', 14),
#  ('depressant', 14),
#  ('hypothermia', 14),
#  ('containing', 14),
#  ('continuous', 14),
#  ('manifested', 14),
#  ('lorlatinib', 14),
#  ('application', 14),
#  ('rapidly', 14),
#  ('Systemic', 14),
#  ('desvenlafaxine', 14),
#  ('discomfort', 14),
#  ('RHD', 14),
#  ('II', 14),
#  ('dutasteride', 14),
#  ('brexanolone', 14),
#  ('Toxic', 13),
#  ('0.1', 13),
#  ('benign', 13),
#  ('clastogenicity', 13),
#  ('infections', 13),
#  ('laboratory', 13),
#  ('transgenic', 13),
#  ('salivation', 13),
#  ('induction', 13),
#  ('center', 13),
#  ('Monitor', 13),
#  ('neonates', 13),
#  ('requiring', 13),
#  ('depending', 13),
#  ('aripiprazole', 13),
#  (' \r\n\r\n', 13),
#  ('behavior', 13),
#  ('postmarketing', 13),
#  ('outcome', 13),
#  ('mean', 13),
#  ('treating', 13),
#  ('absence', 13),
#  ('properties', 13),
#  ('21', 13),
#  ('1500', 13),
#  ('speech', 13),
#  ('coordination', 13),
#  ('guinea', 13),
#  ('peritoneal', 13),
#  ('QTc', 13),
#  ('resolved', 13),
#  ('redness', 13),
#  ('hot', 13),
#  ('sinus', 13),
#  ('safe', 13),
#  ('naloxone', 13),
#  ('needed', 13),
#  ('sildenafil', 13),
#  ('differences', 13),
#  ('Human', 13),
#  ('excitement', 13),
#  ('spasms', 13),
#  ('Supportive', 13),
#  ('Available', 13),
#  ('additional', 13),
#  ('tiredness', 13),
#  ('Mutagenesis', 13),
#  ('infarction', 13),
#  ('physician', 13),
#  ('poisoning', 13),
#  ('capsules', 13),
#  ('intentional', 13),
#  ('attention', 13),
#  ('avoid', 13),
#  ('consideration', 13),
#  ('impair', 13),
#  ('F3181', 13),
#  ('F3184', 13),
#  ('myalgia', 13),
#  ('indicate', 13),
#  ('lethality', 13),
#  ('min', 13),
#  ('0', 13),
#  ('Additionally', 13),
#  ('Cmax', 13),
#  ('different', 13),
#  ('adrenergic', 13),
#  ('association', 13),
#  ('opioid', 13),
#  ('erdafitinib', 13),
#  ('dryness', 13),
#  ('enalapril', 13),
#  ('adenoma', 12),
#  ...]

# %% [markdown]
# Hand picked words

# %%
toxicity_related_frequent_words = ["adverse",'toxicity','LD50','nausea','vomiting','renal','hypotension','severe',
                                    'pain','fetal','pregnancy','reactions','fertility','blood','cardiac',"overdosage",'respiratory'
                                    ,'symptomatic','diarrhea','acute','headache','gastrointestinal','depression',"dizziness","coma",
                                    'liver','failure','mutagenic','acid','heart','abdominal','bradycardia','impairment','convulsions',
                                    'hypertension','anemia','anaphylactic','anaphylaxis','arrhythmias','arrhythmia','asthma','bronchospasm',
                                    'bronchial','cancer','carcinogenic','carcinogenicity','cardiotoxicity','cardiovascular','gastric',
                                    'seizures','confusion','hepatic',"carcinogenicity",'death','rash','mutation','arrhythmias',
                                    "overdose","patients", "effects","adverse","toxicity","symptoms","nausea","vomiting","treatment",
                                    "renal","hypotension","pregnancy","severe","pain","fetal","reactions","fertility","cardiac","diarrhea",
                                    "headache","gastrointestinal","depression","dizziness","coma","respiratory","symptomatic","acne",
                                    "liver","failure","drowsiness","seizures","muscle","maternal","gastric","hypertension","death",
                                    "rash","bladder","edema","children","weakness","insomnia","syndrome","anemia","tumors","acidosis",
                                    "impaired","infant","pediatric","hallucinations","nervous","irritation","fever","constipation",
                                    "adenomas","birth","gestation","developmental","prolonged","mutagenicity","lethal","fatigue",
                                    "sedation","thrombocytopenia","bradycardia","tachycardia","convulsions","arrhythmias","CNS","somnolence",
                                    "hemodialysis","breast","acne","hepatotoxicity","pulmonary","malformations","thrombocytopenia",
                                    "lactation","ventricular","sweating","atropine","kidney","hepatotoxicity","restlessness",
                                    "seizure","emesis","adrenal","carcinomas","neutropenia","allergy","toxicity","arrhythmias","hypertension"]

high_severity = ["cancer","coma","severe","overdose","death","lethal","serious","life-threatening","life threatening","strokes","fatal","mortality"]

# %%
toxicity_related_frequent_words = np.unique(toxicity_related_frequent_words)

low_severity = [word for word in toxicity_related_frequent_words if word not in high_severity]

# %%
import re
from bs4 import BeautifulSoup  # Use BeautifulSoup for HTML tag removal

# Function to parse text and find lowest LD50 value if there is any
def parse_lowest_ld50(report):
    clean_report = BeautifulSoup(report, "html.parser").get_text()
    matches = re.findall(r"LD50[^\d]*(\d+)\s*mg/kg", clean_report, re.IGNORECASE)
    if matches:
        # Convert matches to int and find the minimum
        ld50_values = list(map(int, matches))
        return int(min(ld50_values))
    return 0  # No LD50 value found


# Assign a severity score to each drug based on LD50 value (score pseudo-arbitrary)
def assign_severity_score(ld50):
    if ld50 is None:
        return 0  # No value, no score
    if ld50 < 5000 and ld50 > 0:
        return max(5 - ld50/5000,0)
    else :
        return 0

# %% [markdown]
# ## Toxicity scoring
# The toxicity score is made from adding the score from a possible LD50 value, and weighted number of severity/toxicity/... related words. This score is then normalized by the word length of the toxicity report.

# %%
# all
grouped_df["toxicity_score"] =  grouped_df["unique_toxicity"].apply(lambda x: (sum(3 for word in high_severity if word in str(x)) + sum(1 for word in low_severity if word in str(x)) + int(assign_severity_score(parse_lowest_ld50(str(x))))) )
grouped_df["toxicity_score"] =  grouped_df["toxicity_score"]/grouped_df["unique_toxicity"].apply(lambda x: len(str(x).split()) if len(str(x).split()) != 0 else 0)

# cancer most studied
grouped_df_studied["toxicity_score"] =  grouped_df_studied["unique_toxicity"].apply(lambda x: (sum(3 for word in high_severity if word in str(x)) + sum(1 for word in low_severity if word in str(x)) + (assign_severity_score(parse_lowest_ld50(str(x))))) )
grouped_df_studied["toxicity_score"] =  grouped_df_studied["toxicity_score"]/grouped_df_studied["unique_toxicity"].apply(lambda x: len(str(x).split()) if len(str(x).split()) != 0 else 0)
# Out:
# /var/folders/_h/sv2httr97w1d8pv18rsdrqhc0000gn/T/ipykernel_61094/971890102.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_report = BeautifulSoup(report, "html.parser").get_text()
# /var/folders/_h/sv2httr97w1d8pv18rsdrqhc0000gn/T/ipykernel_61094/971890102.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_report = BeautifulSoup(report, "html.parser").get_text()

# %% [markdown]
# ### Data frame with only non-empty toxicity report

# %%
grouped_df_tox = grouped_df.loc[grouped_df["unique_toxicity"].isna() == False]
grouped_df_studied_tox = grouped_df_studied.loc[grouped_df_studied["unique_toxicity"].isna() == False]

# %% [markdown]
# #### Without empty tox report

# %%
sns.histplot(grouped_df_tox["toxicity_score"], bins=50)
sns.histplot(grouped_df_studied_tox["toxicity_score"], bins=50,color="red")

plt.yscale("log")
plt.xlabel("Toxicity")
plt.title("Histogram of toxicity score")
plt.legend(["All drugs","Drugs tested on the 11 most\nstudied cancer-related proteins"])

# %%
sns.scatterplot(grouped_df_tox,x="toxicity_score",y = "count",alpha = 0.2)
sns.scatterplot(grouped_df_studied_tox,x="toxicity_score",y = "count",alpha = 0.4,color="red")

plt.xlabel("Toxicity score")
plt.ylabel("Number of ligand-protein pairs measured")
# plt.yscale("log")
plt.title("Amount of research vs toxicity score")
plt.legend(["All drugs","Drugs tested on the 11 most\nstudied cancer-related proteins"])

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

temp = grouped_df_tox.copy()
# temp = temp.loc[temp['toxicity_score'] > 0]
temp = temp.dropna()
# Fit a linear regression with normal data
X = np.array(temp['toxicity_score'])
y = np.array(temp['count'])

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(X, y)

# Print the results
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")

# Plot the data points
plt.scatter(X, y, color='blue', label='Data',alpha = 0.1)

# Plot the fitted line
plt.plot(X, slope*X + intercept, color='red', label=f"Fitted Line: Slope = {slope:.2f}")
plt.xlabel("Toxicity Score")
plt.ylabel("Count")
plt.title("Linear Fit: Toxicity Score vs number of entries per drug")
plt.legend()
plt.show()
# Out:
# Slope: -20.434410905420663
# Intercept: 52.370044920711734
# R-squared: 0.0008394516763229761
# P-value: 0.2771149400385663
